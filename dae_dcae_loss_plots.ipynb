# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Path to your Excel file
excel_path = Path("dae_dcae_losses.xlsx")

# Load all sheets
xls = pd.ExcelFile(excel_path)
print(f"Sheets found: {xls.sheet_names}")

for sheet in xls.sheet_names:
    # Read sheet
    df = pd.read_excel(excel_path, sheet_name=sheet)

    # Plot loss curves
    plt.figure(figsize=(8, 5))
    plt.plot(df["epoch"], df["loss"], label="Train Loss")
    plt.plot(df["epoch"], df["val_loss"], label="Validation Loss")

    plt.title(f"Loss Curve — {sheet}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()

    # Save and show
    out_name = f"loss_{sheet}.png"
    plt.savefig(out_name, dpi=150)
    print(f"Saved {out_name}")
    plt.show()
# Out:
# Sheets found: ['BR-DAE', 'BR-DCAE', 'ECV-DAE', 'ECV-DCAE', 'FF-DAE', 'FF-DCAE']
# Saved loss_BR-DAE.png
# Saved loss_BR-DCAE.png
# Saved loss_ECV-DAE.png
# Saved loss_ECV-DCAE.png
# Saved loss_FF-DAE.png
# Saved loss_FF-DCAE.png
