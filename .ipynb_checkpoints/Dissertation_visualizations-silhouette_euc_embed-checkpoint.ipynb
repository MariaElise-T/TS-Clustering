# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

import numpy as np
from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler
import seaborn as sns
from tslearn.utils import to_time_series_dataset
from tslearn.clustering import silhouette_score

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import sklearn.cluster

import os
from yellowbrick.cluster import SilhouetteVisualizer

import math
import scipy

from sklearn.metrics import adjusted_rand_score

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from tslearn.metrics import soft_dtw

# %%
def ts_cluster_visualization(y_pred, df, n_clusters, plot_title):
    ts_size = df.shape[1]
    ts_max = df.max()
    plt.figure()
    for cluster in range(n_clusters):
        plt.subplot(4, math.ceil(n_clusters/4), cluster+1)
        for ts in df[y_pred == cluster]:
            plt.plot(ts.ravel(), "k-", alpha=.2)
        plt.plot(np.mean(df[y_pred == cluster], axis=0), "r-")
        plt.xlim(0, ts_size)
        plt.ylim(0, ts_max)
        plt.text(0.55, 0.35,'Cluster %d' % (cluster),
                 transform=plt.gca().transAxes)
        if cluster == 1:
            plt.title(plot_title)      
    plt.tight_layout()
    plt.show()

# %%
def import_ff_data(filename):
    expected_columns=155
    data = []
    with open(filename, 'r') as file:
        for line in file:
            row = line.strip().split(',')
            if len(row) < expected_columns:
                row += [np.nan] * (expected_columns - len(row))
            data.append(row)
    df = pd.DataFrame(data)
    def fill_last_valid(row):
        for i in range(1, len(row)):
            if pd.isna(row[i]):
                row[i] = row[i - 1]  
        return row
    df_filled = df.apply(fill_last_valid, axis=1)
    return df_filled

# %% [markdown]
# # K means only plot

# %% [markdown]
# ## Get no-embedding baselines

# %%
poor = pd.read_csv("SimData/bank_reserves_outputs_poor.csv", header=None)
middle = pd.read_csv("SimData/bank_reserves_outputs_middle.csv", header=None)
rich = pd.read_csv("SimData/bank_reserves_outputs_rich.csv", header=None)

br_combined = pd.concat([poor, middle, rich], axis=1)
br_combined = StandardScaler().fit_transform(br_combined)

k = 7   
kmeans = KMeans(n_clusters=k, random_state=42)
br_baseline_labels = kmeans.fit_predict(br_combined)
# Out:
# C:\Users\met48\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
br_baseline_labels
# Out:
# array([6, 5, 0, ..., 3, 4, 4])

# %%
#distance_br_no_embedding_kmeans = ts_cluster_distance_silhouette(br_baseline_labels, poor.to_numpy(), middle.to_numpy(), rich.to_numpy(), 7)
import sklearn.metrics as m; 
br_none_kmeans = m.silhouette_score(br_combined, br_baseline_labels, metric='euclidean')

# %%
ecv_active = pd.read_csv("SimData/epsteinCV_outputs_active.csv", header=None)
ecv_jailed = pd.read_csv("SimData/epsteinCV_outputs_jailed.csv", header=None)
ecv_quiet = pd.read_csv("SimData/epsteinCV_outputs_quiet.csv", header=None)

ecv_combined = pd.concat([ecv_active, ecv_jailed, ecv_quiet], axis=1)
ecv_combined = StandardScaler().fit_transform(ecv_combined)

k = 8   
kmeans = KMeans(n_clusters=k, random_state=42)
ecv_baseline_labels = kmeans.fit_predict(ecv_combined)

# %%
ecv_none_kmeans = m.silhouette_score(ecv_combined, ecv_baseline_labels, metric='euclidean')

# %%
ff_onfire = import_ff_data("SimData/forest_fire_outputs_onfire.csv")
ff_fine = import_ff_data("SimData/forest_fire_outputs_fine.csv")
ff_burned = import_ff_data("SimData/forest_fire_outputs_burned.csv")

ff_combined = pd.concat([ff_onfire, ff_fine, ff_burned], axis=1)
ff_combined = StandardScaler().fit_transform(ff_combined)

k = 4   
kmeans = KMeans(n_clusters=k, random_state=42)
ff_baseline_labels = kmeans.fit_predict(ff_combined)

# %%
ff_none_kmeans = m.silhouette_score(ff_combined, ff_baseline_labels, metric='euclidean')

# %% [markdown]
# ## PCA

# %%
label_results = pd.read_csv('bank_reserves_results.csv', index_col=0)
df = pd.read_csv('extracted_features/bank_reserves_PCA_standardized.csv', index_col=0)
br_pca_kmeans = m.silhouette_score(df, label_results.loc["PCA_KMeans"].to_numpy(), metric='euclidean')

# %%
label_results = pd.read_csv('epstein_results.csv', index_col=0)
df = pd.read_csv('extracted_features/epstein_PCA_standardized.csv', index_col=0)
ecv_pca_kmeans = m.silhouette_score(df, label_results.loc["PCA_KMeans"].to_numpy(), metric='euclidean')

# %%
label_results = pd.read_csv('forestfire_results.csv', index_col=0)
df = pd.read_csv('extracted_features/forestfire_PCA_standardized.csv', index_col=0)
ff_pca_kmeans = m.silhouette_score(df, label_results.loc["PCA_KMeans"].to_numpy(), metric='euclidean')

# %% [markdown]
# ## DAE

# %%
label_results = pd.read_csv('bank_reserves_results.csv', index_col=0)
df = pd.read_csv('extracted_features/bank_reserves_DAE.csv', header=None)
br_dae_kmeans = m.silhouette_score(df, label_results.loc["DAE_KMeans"].to_numpy(), metric='euclidean')

# %%
label_results = pd.read_csv('epstein_results.csv', index_col=0)
df = pd.read_csv('extracted_features/epstein_DAE.csv', header=None)
ecv_dae_kmeans = m.silhouette_score(df, label_results.loc["DAE_KMeans"].to_numpy(), metric='euclidean')

# %%
label_results = pd.read_csv('forestfire_results.csv', index_col=0)
df = pd.read_csv('extracted_features/forestfire_DAE.csv', header=None)
ff_dae_kmeans = m.silhouette_score(df, label_results.loc["DAE_KMeans"].to_numpy(), metric='euclidean')

# %% [markdown]
# ## DCAE

# %%
label_results = pd.read_csv('bank_reserves_results.csv', index_col=0)
df = pd.read_csv('extracted_features/bank_reserves_DCAE.csv', header=None)
br_dcae_kmeans = m.silhouette_score(df, label_results.loc["DCAE_KMeans"].to_numpy(), metric='euclidean')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 label_results = pd.read_csv('bank_reserves_results.csv', index_col=0)
#       2 df = pd.read_csv('extracted_features/bank_reserves_DCAE.csv', header=None)
# ----> 3 br_dcae_kmeans = m.silhouette_score(df, label_results.loc["DCAE_KMeans"].to_numpy(), metric='euclidean')
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:141, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     139     else:
#     140         X, labels = X[indices], labels[indices]
# --> 141 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:305, in silhouette_samples(X, labels, metric, **kwds)
#     301 kwds["metric"] = metric
#     302 reduce_func = functools.partial(
#     303     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     304 )
# --> 305 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     306 intra_clust_dists, inter_clust_dists = results
#     307 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:2172, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2170 else:
#    2171     X_chunk = X[sl]
# -> 2172 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2173 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2174     metric, None
#    2175 ) is euclidean_distances:
#    2176     # zeroing diagonal, taking care of aliases of "euclidean",
#    2177     # i.e. "l2"
#    2178     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:2375, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2372         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2373     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2375 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:1893, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1890 X, Y, dtype = _return_float_dtype(X, Y)
#    1892 if effective_n_jobs(n_jobs) == 1:
# -> 1893     return func(X, Y, **kwds)
#    1895 # enforce a threading backend to prevent data communication overhead
#    1896 fd = delayed(_dist_wrapper)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:372, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     366     if Y_norm_squared.shape != (1, Y.shape[0]):
#     367         raise ValueError(
#     368             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     369             f"Y_norm_squared of shape {original_shape}."
#     370         )
# --> 372 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:410, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     408     distances += XX
#     409     distances += YY
# --> 410 np.maximum(distances, 0, out=distances)
#     412 # Ensure that distances between vectors and themselves are set to 0.0.
#     413 # This may not be the case due to floating point rounding errors.
#     414 if X is Y:
#
# KeyboardInterrupt:

# %%
label_results = pd.read_csv('epstein_results.csv', index_col=0)
df = pd.read_csv('extracted_features/epstein_DCAE.csv', header=None)
ecv_dcae_kmeans = m.silhouette_score(df, label_results.loc["DCAE_KMeans"].to_numpy(), metric='euclidean')

# %%
label_results = pd.read_csv('forestfire_results.csv', index_col=0)
df = pd.read_csv('extracted_features/forestfire_DCAE.csv', header=None)
ff_dcae_kmeans = m.silhouette_score(df, label_results.loc["DCAE_KMeans"].to_numpy(), metric='euclidean')

# %% [markdown]
# ## Enhanced DAE

# %%
df = pd.read_csv('extracted_features/0_DAE_5_2_2048_linear.csv', header=None)
label_results = KMeans(n_clusters=7, random_state=42, n_init=10).fit(df).labels_
br_dae_plus_kmeans = m.silhouette_score(df, label_results, metric='euclidean')

# %%
df = pd.read_csv('extracted_features/1_DAE_5_3_2048_linear.csv', header=None)
label_results = KMeans(n_clusters=8, random_state=42, n_init=10).fit(df).labels_
ecv_dae_plus_kmeans = m.silhouette_score(df, label_results, metric='euclidean')

# %%
df = pd.read_csv('extracted_features/2_DAE_3_3_2048_linear.csv', header=None)
label_results = KMeans(n_clusters=4, random_state=42, n_init=10).fit(df).labels_
ff_dae_plus_kmeans = m.silhouette_score(df, label_results, metric='euclidean')

# %% [markdown]
# ## Format

# %%
models = ['Bank Reserves', 'Bank Reserves', 'Bank Reserves', 'Bank Reserves', 'Bank Reserves',
                                    'Epstein', 'Epstein', 'Epstein', 'Epstein', 'Epstein',
                                    'Forest Fire', 'Forest Fire', 'Forest Fire', 'Forest Fire', 'Forest Fire']

# %%
df_kmeans = pd.DataFrame({'Model': ['Bank Reserves', 'Bank Reserves', 'Bank Reserves', 'Bank Reserves', 'Bank Reserves',
                                    'Epstein', 'Epstein', 'Epstein', 'Epstein', 'Epstein',
                                    'Forest Fire', 'Forest Fire', 'Forest Fire', 'Forest Fire', 'Forest Fire'], 
                        'Feature Embedding': ['None', 'PCA', 'DCAE', 'DAE', 'DAE+',
                                              'None', 'PCA', 'DCAE', 'DAE', 'DAE+',
                                              'None', 'PCA', 'DCAE', 'DAE', 'DAE+'], 
                        'Silhouette Score': [br_none_kmeans, br_pca_kmeans, br_dcae_kmeans, br_dae_kmeans, br_dae_plus_kmeans,
                                            ecv_none_kmeans, ecv_pca_kmeans, ecv_dcae_kmeans, ecv_dae_kmeans, ecv_dae_plus_kmeans,
                                            ff_none_kmeans, ff_pca_kmeans, ff_dcae_kmeans, ff_dae_kmeans, ff_dae_plus_kmeans]
                         })

# %%
df_kmeans

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_kmeans, x="Model", y="Silhouette Score", hue="Feature Embedding")

# Customize the plot
plt.xlabel("Model")
plt.ylabel("Silhouette Score")
plt.title("K-Means Clustering")
plt.legend(title="Feature Embedding")
plt.ylim(0, 1)
plt.savefig("kmeans_embedding_enh_comp.png", format="png")
plt.show()

# %% [markdown]
# # Motifs

# %%
def ts_cluster_visualization2(y_pred, df, n_clusters, plot_title=None):
    """
    Plot only the cluster center (mean) curves for all clusters on a single plot.

    Parameters
    ----------
    y_pred : array-like of shape (n_samples,)
        Cluster labels for each time series (assumed 0..n_clusters-1).
    df : array-like of shape (n_samples, T)
        Time-series data; rows = series, columns = timesteps.
        Can be a NumPy array or a pandas DataFrame.
    n_clusters : int
        Number of clusters.
    plot_title : str, optional
        Title for the plot.
    """
    # Ensure we can index like a NumPy array
    X = np.asarray(df)
    ts_size = X.shape[1]
    ts_max = np.nanmax(X)

    plt.figure(figsize=(9, 5))
    for c in range(n_clusters):
        mask = (y_pred == c)
        if not np.any(mask):
            continue  # skip empty clusters gracefully
        center = np.nanmean(X[mask], axis=0)
        plt.plot(center.ravel(), linewidth=2, label=f"Cluster {c}")

    plt.xlim(0, ts_size - 1)
    plt.ylim(0, ts_max)
    if plot_title:
        plt.title(plot_title)
    plt.xlabel("Timestep")
    plt.ylabel("Value")
    plt.legend(frameon=False)
    plt.tight_layout()
    #plt.show()

# %% [markdown]
# ## Bank Reserves

# %%
poor = pd.read_csv("SimData/bank_reserves_outputs_poor.csv", header=None)
X_train = to_time_series_dataset(poor)

# %%
ts_cluster_visualization2(br_baseline_labels, X_train, 7, "Bank Reserves, No Embedding, K-Means")
plt.savefig("br_no_embedding_centers.png", format="png")

# %%
label_results = pd.read_csv('bank_reserves_results.csv', index_col=0)

# %%
ts_cluster_visualization2(label_results.loc["PCA_KMeans"].to_numpy(), X_train, 7, "Bank Reserves, PCA Embedding, K-Means")
plt.savefig("br_pca_embedding_centers.png", format="png")

# %%
df = pd.read_csv('extracted_features/0_DAE_5_2_2048_linear.csv', header=None)
label_results = KMeans(n_clusters=7, random_state=42, n_init=10).fit(df).labels_

# %%
ts_cluster_visualization2(label_results, X_train, 7, "Bank Reserves, DAE+ Embedding, K-Means")
plt.savefig("br_dae_plus_embedding_centers.png", format="png")

# %% [markdown]
# ## Epstein

# %%
poor = pd.read_csv("SimData/epsteinCV_outputs_active.csv", header=None)
X_train = to_time_series_dataset(poor)
sz = X_train.shape[1]
ts_cluster_visualization2(ecv_baseline_labels, X_train, 8, "Epstein, No Embedding, K-Means")
plt.savefig("ecv_no_embedding_centers.png", format="png")

# %%
label_results = pd.read_csv('epstein_results.csv', index_col=0)
ts_cluster_visualization2(label_results.loc["PCA_KMeans"].to_numpy(), X_train, 8, "Epstein, PCA Embedding, K-Means")
plt.savefig("ecv_pca_embedding_centers.png", format="png")

# %%
new_embedding = pd.read_csv("extracted_features/1_DAE_5_6_2048_linear.csv", header=None)

k = 8   
kmeans = KMeans(n_clusters=k, random_state=42)
label_results = kmeans.fit_predict(new_embedding)
ts_cluster_visualization2(label_results, X_train, 8, "Epstein, DAE+ Embedding, K-Means")
plt.savefig("ecv_dae_plus_embedding_centers.png", format="png")

# %% [markdown]
# ## Forest Fire

# %%
poor = ff_burned
X_train = to_time_series_dataset(poor)
sz = X_train.shape[1]
label_results = pd.read_csv('forestfire_results.csv', index_col=0)
ts_cluster_visualization2(label_results.loc["PCA_KMeans"].to_numpy(), X_train, 4, "Forest Fire, PCA Embedding, K-Means")
plt.savefig("ff_PCA_embedding_centers.png", format="png")

# %%
ts_cluster_visualization2(ff_baseline_labels, X_train, 4, "Forest Fire, No Embedding, K-Means")
plt.savefig("ff_no_embedding_centers.png", format="png")

# %%
new_embedding = pd.read_csv("extracted_features/2_DAE_3_3_2048_linear.csv", header=None)

k = 4   
kmeans = KMeans(n_clusters=k, random_state=42)
label_results = kmeans.fit_predict(new_embedding)
ts_cluster_visualization2(label_results, X_train, 4, "Forest Fire, DAE+ Embedding, K-Means")
plt.savefig("ff_dae_plus_embedding_centers.png", format="png")

# %%
poor = pd.read_csv("SimData/bank_reserves_outputs_poor.csv", header=None)
middle = pd.read_csv("SimData/bank_reserves_outputs_middle.csv", header=None)
rich = pd.read_csv("SimData/bank_reserves_outputs_rich.csv", header=None)
sc = StandardScaler()
br = []
for i in np.arange(0, poor.shape[0]):
    sample = pd.concat([poor.iloc[i], middle.iloc[i]], axis=0).T
    sample = pd.concat([sample, rich.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    br.append(sample_std)

# %%
ecv_active = pd.read_csv("SimData/epsteinCV_outputs_active.csv", header=None)
ecv_jailed = pd.read_csv("SimData/epsteinCV_outputs_jailed.csv", header=None)
ecv_quiet = pd.read_csv("SimData/epsteinCV_outputs_quiet.csv", header=None)
sc = StandardScaler()
ecv = []
for i in np.arange(0, ecv_active.shape[0]):
    sample = pd.concat([ecv_active.iloc[i], ecv_jailed.iloc[i]], axis=0).T
    sample = pd.concat([sample, ecv_quiet.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    ecv.append(sample_std)

# %%
def import_ff_data(filename):
    expected_columns=155
    data = []
    with open(filename, 'r') as file:
        for line in file:
            row = line.strip().split(',')
            if len(row) < expected_columns:
                row += [np.nan] * (expected_columns - len(row))
            data.append(row)
    df = pd.DataFrame(data)
    def fill_last_valid(row):
        for i in range(1, len(row)):
            if pd.isna(row[i]):
                row[i] = row[i - 1]  
        return row
    df_filled = df.apply(fill_last_valid, axis=1)
    return df_filled

# %%
ff_onfire = import_ff_data("SimData/forest_fire_outputs_onfire.csv")
print("check 1")
ff_fine = import_ff_data("SimData/forest_fire_outputs_fine.csv")
print("check 2")
ff_burned = import_ff_data("SimData/forest_fire_outputs_burned.csv")
sc = StandardScaler()
ff = []
for i in np.arange(0, ff_onfire.shape[0]):
    sample = pd.concat([ff_onfire.iloc[i], ff_fine.iloc[i]], axis=0).T
    sample = pd.concat([sample, ff_burned.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    ff.append(sample_std)
# Out:
# check 1
# check 2

# %%
RANDOM_STATE = 42

# %%
from sklearn.metrics import silhouette_score
debug = 1
sil_sample = 20000 # sample 

def sil_score(X_embed, labels, s): 
    SILH_SAMPLE = s 
    if SILH_SAMPLE is not None and SILH_SAMPLE < X_embed.shape[0]:
        rng = np.random.default_rng(RANDOM_STATE)
        idx = rng.choice(X_embed.shape[0], size=SILH_SAMPLE, replace=False)
        sil = silhouette_score(X_embed[idx], labels[idx], metric="euclidean")
    else:
        sil = silhouette_score(X_embed, labels, metric="euclidean")

    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique.tolist(), counts.tolist()))
    if debug:
        print(f"Silhouette Score: {sil:.4f}")
      #  print("Cluster sizes:", cluster_sizes)
    return sil

# %%
flat_list = [sample.flatten() for sample in br]
raw_features = np.asarray(flat_list)
raw_labels = KMeans(n_clusters=7, random_state=RANDOM_STATE, n_init=10).fit(raw_features).labels_

# %%
poor = pd.read_csv("SimData/bank_reserves_outputs_poor.csv", header=None)
X_train = to_time_series_dataset(poor)

# %%
ts_cluster_visualization2(raw_labels, X_train, 7, "Bank Reserves, No Embedding, K-Means")
plt.savefig("br_no_embedding_centers.png", format="png")

# %%
flat_list = [sample.flatten() for sample in ecv]
raw_features = np.asarray(flat_list)
raw_labels = KMeans(n_clusters=8, random_state=RANDOM_STATE, n_init=10).fit(raw_features).labels_

# %%
poor = pd.read_csv("SimData/epsteinCV_outputs_active.csv", header=None)
X_train = to_time_series_dataset(poor)

# %%
ts_cluster_visualization2(raw_labels, X_train, 8, "Epstein Civil Violence, No Embedding, K-Means")
plt.savefig("ecv_no_embedding_centers.png", format="png")

# %%
flat_list = [sample.flatten() for sample in ff]
raw_features = np.asarray(flat_list)
raw_labels = KMeans(n_clusters=4, random_state=RANDOM_STATE, n_init=10).fit(raw_features).labels_

# %%
poor = ff_burned
X_train = to_time_series_dataset(poor)

# %%
ts_cluster_visualization2(raw_labels, X_train, 4, "Forest Fire, No Embedding, K-Means")
plt.savefig("ff_no_embedding_centers.png", format="png")

# %%
raw_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 raw_data
#
# NameError: name 'raw_data' is not defined
