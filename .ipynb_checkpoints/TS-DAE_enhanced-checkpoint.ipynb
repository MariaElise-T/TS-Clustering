# %%
from keras.models import Model 
from keras.layers import Input, Convolution2D, MaxPooling2D, Dense, Dropout, Flatten, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
# import np_utils
import numpy as np
import pandas as pd
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.optimizers import Adam
from keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
import os
import datetime
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

# %%
poor = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/bank_reserves_outputs_poor.csv", header=None)
middle = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/bank_reserves_outputs_middle.csv", header=None)
rich = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/bank_reserves_outputs_rich.csv", header=None)
sc = StandardScaler()
bank_reserves = []
for i in np.arange(0, poor.shape[0]):
    sample = pd.concat([poor.iloc[i], middle.iloc[i]], axis=0).T
    sample = pd.concat([sample, rich.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    bank_reserves.append(sample_std)

# %%
ecv_active = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/epsteinCV_outputs_active.csv", header=None)
ecv_jailed = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/epsteinCV_outputs_jailed.csv", header=None)
ecv_quiet = pd.read_csv("C:/Users/met48/Desktop/TS-Clustering/SimData/epsteinCV_outputs_quiet.csv", header=None)
sc = StandardScaler()
ecv = []
for i in np.arange(0, ecv_active.shape[0]):
    sample = pd.concat([ecv_active.iloc[i], ecv_jailed.iloc[i]], axis=0).T
    sample = pd.concat([sample, ecv_quiet.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    ecv.append(sample_std)

# %%
def import_ff_data(filename):
    expected_columns=155
    data = []
    with open(filename, 'r') as file:
        for line in file:
            row = line.strip().split(',')
            if len(row) < expected_columns:
                row += [np.nan] * (expected_columns - len(row))
            data.append(row)
    df = pd.DataFrame(data)
    def fill_last_valid(row):
        for i in range(1, len(row)):
            if pd.isna(row[i]):
                row[i] = row[i - 1]  
        return row
    df_filled = df.apply(fill_last_valid, axis=1)
    return df_filled

# %%
ff_onfire = import_ff_data("C:/Users/met48/Desktop/TS-Clustering/SimData/forest_fire_outputs_onfire.csv")
print("check 1")
ff_fine = import_ff_data("C:/Users/met48/Desktop/TS-Clustering/SimData/forest_fire_outputs_fine.csv")
print("check 2")
ff_burned = import_ff_data("C:/Users/met48/Desktop/TS-Clustering/SimData/forest_fire_outputs_burned.csv")
sc = StandardScaler()
ff = []
for i in np.arange(0, ff_onfire.shape[0]):
    sample = pd.concat([ff_onfire.iloc[i], ff_fine.iloc[i]], axis=0).T
    sample = pd.concat([sample, ff_burned.iloc[i]], axis=0).T
    sample_std = sc.fit_transform(sample.to_frame())
    ff.append(sample_std)
# Out:
# check 1
# check 2

# %%
# Silouhette score 

from sklearn.metrics import silhouette_score
def sil_score(X_embed, labels, s): 
    SILH_SAMPLE = s 
    RANDOM_STATE = 42

    if SILH_SAMPLE is not None and SILH_SAMPLE < X_embed.shape[0]:
        rng = np.random.default_rng(RANDOM_STATE)
        idx = rng.choice(X_embed.shape[0], size=SILH_SAMPLE, replace=False)
        sil = silhouette_score(X_embed[idx], labels[idx], metric="euclidean")
    else:
        sil = silhouette_score(X_embed, labels, metric="euclidean")

    unique, counts = np.unique(labels, return_counts=True)
    cluster_sizes = dict(zip(unique.tolist(), counts.tolist()))
    print(f"[Kmeans, DAE] Silhouette: {sil:.4f}")
#    print("Cluster sizes:", cluster_sizes)
    return sil

# %%
import tensorflow as tf

def DAE_reduction(df, bottleneck, ep, batch):
    df_flat = [sample.flatten() for sample in df]
    df_flat = np.asarray(df_flat)
    train, test = train_test_split(df_flat, test_size=0.20, random_state=42)
    input = Input(shape=(df_flat.shape[1],))

    encoded = Dense(30, activation='relu')(input)
    encoded = Dense(20, activation='relu')(encoded)
    encoded = Dense(10, activation='relu')(encoded)
    encoded = Dense(bottleneck, activation='linear', name='bottleneck')(encoded)

    decoded = Dense(bottleneck, activation='relu')(encoded)
    decoded = Dense(20, activation='relu')(decoded)
    decoded = Dense(30, activation='relu')(decoded)
    output = Dense(df_flat.shape[1], activation=None)(decoded)

    autoencoder = Model(input, output)
#   autoencoder.summary()
#    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    huber = tf.keras.losses.Huber()
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss=huber)
    autoencoder.fit(train, train,
     epochs=ep,
     batch_size=batch,
     shuffle=True,
     validation_data=(test, test), verbose = 0)
    encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('bottleneck').output)
    encoded_ts = encoder.predict(df_flat)
    return encoded_ts, encoder

# %%
dae_embeds, dae_model = DAE_reduction(bank_reserves, 3, 3, 2048)
# Out:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step

# %%
#br_dae = DAE_reduction(bank_reserves)
raw_data = []
raw_data.append(bank_reserves)
raw_data.append(ecv)
raw_data.append(ff)

# %%
opt_clusters = []
opt_clusters.append(7)
opt_clusters.append(8)
opt_clusters.append(4)

# %%
# Hyperparameter tuning; 
# hardcoded for DAE with linear bottleneck layer, 2048 batch size and Huber loss; 
# may want to tune them as well

def hypertune(target, k): 
    
    tf.keras.backend.clear_session()
    
    BOTTLENECK_MIN = 3 
    EPOCH_MIN = 2
    
    bottleneck = 9     #  number of desired embeddings; tune in the range of [BOTTLENECK_MIN..bottleneck]
    epochs = 8         #  tune in range of [EPOCH_MIN..epochs] 
    batch = 2048       #  fixed from prior trials 
    evals = 5          #  number of repeated trainings to reduce noise in model 
  
    sil_sample = 20000 # silohouette sample 

    max_sil_score = 0         # max silohouette score 
    best_embed = []           # best emebeddings 
    best_model = []   # model that produced the best embeddings 
    
    for b in np.arange(BOTTLENECK_MIN, bottleneck + 1):   # bottleneck 
        for e in np.arange(EPOCH_MIN, epochs + 1):        # epoch
            for i in np.arange(1, evals + 1):             # evals 
                
                print(f"Evaluation: embeddings {b}, epoch {e}, eval # {i}:")
                # get embeddings 
                dae_embeds, dae_model = DAE_reduction(raw_data[target], b, e, batch)

                # clustering 
                dae_kmeans_labels = KMeans(n_clusters=k, random_state=42, n_init=10).fit(dae_embeds).labels_

                # silhouette score 
                score = sil_score(dae_embeds, dae_kmeans_labels, sil_sample)

                # save the best embeddings and model   
                if (score > max_sil_score): 
                    max_sil_score = score
                    best_embed = dae_embeds
                    best_model.append(dae_model) # assuming we are hypertuning the three models in order  
                    best_params = str(b) + '_' + str(e) + '_' + str(batch) + '_linear'
 
    print(f"Silhouette: {max_sil_score:.4f}")
    print(f"Best parameters: {best_params}")
    filename = 'C:/Users/met48/Desktop/TS-Clustering/extracted_features/' + str(target) + '_DAE_' + best_params + '.csv'
    np.savetxt(filename, best_embed, delimiter=",")

# %%
hypertune(0,7)
# Out:
# Evaluation: embeddings 3, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 610us/step
# [Kmeans, DAE] Silhouette: 0.5209
# Evaluation: embeddings 3, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 593us/step
# [Kmeans, DAE] Silhouette: 0.4113
# Evaluation: embeddings 3, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 571us/step
# [Kmeans, DAE] Silhouette: 0.5654
# Evaluation: embeddings 3, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 562us/step
# [Kmeans, DAE] Silhouette: 0.5831
# Evaluation: embeddings 3, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.4461
# Evaluation: embeddings 3, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 590us/step
# [Kmeans, DAE] Silhouette: 0.5696
# Evaluation: embeddings 3, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 611us/step
# [Kmeans, DAE] Silhouette: 0.4889
# Evaluation: embeddings 3, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 587us/step
# [Kmeans, DAE] Silhouette: 0.5148
# Evaluation: embeddings 3, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.3541
# Evaluation: embeddings 3, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.4632
# Evaluation: embeddings 3, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 597us/step
# [Kmeans, DAE] Silhouette: 0.3291
# Evaluation: embeddings 3, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 677us/step
# [Kmeans, DAE] Silhouette: 0.5573
# Evaluation: embeddings 3, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 580us/step
# [Kmeans, DAE] Silhouette: 0.5431
# Evaluation: embeddings 3, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.4699
# Evaluation: embeddings 3, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 570us/step
# [Kmeans, DAE] Silhouette: 0.5587
# Evaluation: embeddings 3, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 567us/step
# [Kmeans, DAE] Silhouette: 0.6070
# Evaluation: embeddings 3, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.3912
# Evaluation: embeddings 3, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 619us/step
# [Kmeans, DAE] Silhouette: 0.5164
# Evaluation: embeddings 3, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 623us/step
# [Kmeans, DAE] Silhouette: 0.5535
# Evaluation: embeddings 3, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 581us/step
# [Kmeans, DAE] Silhouette: 0.4745
# Evaluation: embeddings 3, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.4925
# Evaluation: embeddings 3, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 578us/step
# [Kmeans, DAE] Silhouette: 0.5661
# Evaluation: embeddings 3, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.3182
# Evaluation: embeddings 3, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5206
# Evaluation: embeddings 3, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.4103
# Evaluation: embeddings 3, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.5277
# Evaluation: embeddings 3, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 563us/step
# [Kmeans, DAE] Silhouette: 0.5541
# Evaluation: embeddings 3, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 569us/step
# [Kmeans, DAE] Silhouette: 0.3394
# Evaluation: embeddings 3, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 570us/step
# [Kmeans, DAE] Silhouette: 0.5409
# Evaluation: embeddings 3, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 581us/step
# [Kmeans, DAE] Silhouette: 0.5102
# Evaluation: embeddings 3, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 588us/step
# [Kmeans, DAE] Silhouette: 0.4620
# Evaluation: embeddings 3, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step
# [Kmeans, DAE] Silhouette: 0.5553
# Evaluation: embeddings 3, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 571us/step
# [Kmeans, DAE] Silhouette: 0.5388
# Evaluation: embeddings 3, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
# [Kmeans, DAE] Silhouette: 0.4367
# Evaluation: embeddings 3, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.5562
# Evaluation: embeddings 4, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.5220
# Evaluation: embeddings 4, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 724us/step
# [Kmeans, DAE] Silhouette: 0.5225
# Evaluation: embeddings 4, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.4784
# Evaluation: embeddings 4, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 615us/step
# [Kmeans, DAE] Silhouette: 0.5396
# Evaluation: embeddings 4, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.5786
# Evaluation: embeddings 4, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.5551
# Evaluation: embeddings 4, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 624us/step
# [Kmeans, DAE] Silhouette: 0.5591
# Evaluation: embeddings 4, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.5482
# Evaluation: embeddings 4, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 616us/step
# [Kmeans, DAE] Silhouette: 0.5238
# Evaluation: embeddings 4, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.4612
# Evaluation: embeddings 4, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 585us/step
# [Kmeans, DAE] Silhouette: 0.4776
# Evaluation: embeddings 4, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 569us/step
# [Kmeans, DAE] Silhouette: 0.5153
# Evaluation: embeddings 4, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 564us/step
# [Kmeans, DAE] Silhouette: 0.5536
# Evaluation: embeddings 4, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 629us/step
# [Kmeans, DAE] Silhouette: 0.5415
# Evaluation: embeddings 4, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 595us/step
# [Kmeans, DAE] Silhouette: 0.5511
# Evaluation: embeddings 4, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.5595
# Evaluation: embeddings 4, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# [Kmeans, DAE] Silhouette: 0.5357
# Evaluation: embeddings 4, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.5646
# Evaluation: embeddings 4, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 608us/step
# [Kmeans, DAE] Silhouette: 0.4976
# Evaluation: embeddings 4, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# [Kmeans, DAE] Silhouette: 0.4120
# Evaluation: embeddings 4, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 610us/step
# [Kmeans, DAE] Silhouette: 0.4711
# Evaluation: embeddings 4, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 573us/step
# [Kmeans, DAE] Silhouette: 0.5311
# Evaluation: embeddings 4, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 720us/step
# [Kmeans, DAE] Silhouette: 0.5012
# Evaluation: embeddings 4, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.5296
# Evaluation: embeddings 4, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5227
# Evaluation: embeddings 4, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 608us/step
# [Kmeans, DAE] Silhouette: 0.5422
# Evaluation: embeddings 4, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 579us/step
# [Kmeans, DAE] Silhouette: 0.5099
# Evaluation: embeddings 4, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 577us/step
# [Kmeans, DAE] Silhouette: 0.5144
# Evaluation: embeddings 4, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 550us/step
# [Kmeans, DAE] Silhouette: 0.4420
# Evaluation: embeddings 4, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 563us/step
# [Kmeans, DAE] Silhouette: 0.5381
# Evaluation: embeddings 4, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 573us/step
# [Kmeans, DAE] Silhouette: 0.5261
# Evaluation: embeddings 4, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.5161
# Evaluation: embeddings 4, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 567us/step
# [Kmeans, DAE] Silhouette: 0.4692
# Evaluation: embeddings 4, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.5520
# Evaluation: embeddings 4, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 596us/step
# [Kmeans, DAE] Silhouette: 0.5560
# Evaluation: embeddings 5, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 594us/step
# [Kmeans, DAE] Silhouette: 0.5562
# Evaluation: embeddings 5, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 554us/step
# [Kmeans, DAE] Silhouette: 0.6695
# Evaluation: embeddings 5, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 548us/step
# [Kmeans, DAE] Silhouette: 0.5869
# Evaluation: embeddings 5, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.5214
# Evaluation: embeddings 5, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 610us/step
# [Kmeans, DAE] Silhouette: 0.6066
# Evaluation: embeddings 5, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
# [Kmeans, DAE] Silhouette: 0.5050
# Evaluation: embeddings 5, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 597us/step
# [Kmeans, DAE] Silhouette: 0.5247
# Evaluation: embeddings 5, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 582us/step
# [Kmeans, DAE] Silhouette: 0.5843
# Evaluation: embeddings 5, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 624us/step
# [Kmeans, DAE] Silhouette: 0.5413
# Evaluation: embeddings 5, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 626us/step
# [Kmeans, DAE] Silhouette: 0.5859
# Evaluation: embeddings 5, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.5178
# Evaluation: embeddings 5, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 584us/step
# [Kmeans, DAE] Silhouette: 0.5345
# Evaluation: embeddings 5, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 576us/step
# [Kmeans, DAE] Silhouette: 0.4862
# Evaluation: embeddings 5, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 575us/step
# [Kmeans, DAE] Silhouette: 0.5445
# Evaluation: embeddings 5, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step
# [Kmeans, DAE] Silhouette: 0.5347
# Evaluation: embeddings 5, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
# [Kmeans, DAE] Silhouette: 0.5548
# Evaluation: embeddings 5, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 593us/step
# [Kmeans, DAE] Silhouette: 0.5495
# Evaluation: embeddings 5, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 611us/step
# [Kmeans, DAE] Silhouette: 0.5456
# Evaluation: embeddings 5, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.5546
# Evaluation: embeddings 5, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 643us/step
# [Kmeans, DAE] Silhouette: 0.5876
# Evaluation: embeddings 5, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 550us/step
# [Kmeans, DAE] Silhouette: 0.5303
# Evaluation: embeddings 5, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 579us/step
# [Kmeans, DAE] Silhouette: 0.5353
# Evaluation: embeddings 5, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 557us/step
# [Kmeans, DAE] Silhouette: 0.5352
# Evaluation: embeddings 5, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.5218
# Evaluation: embeddings 5, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 572us/step
# [Kmeans, DAE] Silhouette: 0.5905
# Evaluation: embeddings 5, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 549us/step
# [Kmeans, DAE] Silhouette: 0.5212
# Evaluation: embeddings 5, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 585us/step
# [Kmeans, DAE] Silhouette: 0.5594
# Evaluation: embeddings 5, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 605us/step
# [Kmeans, DAE] Silhouette: 0.4803
# Evaluation: embeddings 5, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 585us/step
# [Kmeans, DAE] Silhouette: 0.5603
# Evaluation: embeddings 5, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 583us/step
# [Kmeans, DAE] Silhouette: 0.5163
# Evaluation: embeddings 5, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 593us/step
# [Kmeans, DAE] Silhouette: 0.5267
# Evaluation: embeddings 5, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.5878
# Evaluation: embeddings 5, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 623us/step
# [Kmeans, DAE] Silhouette: 0.5804
# Evaluation: embeddings 5, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 595us/step
# [Kmeans, DAE] Silhouette: 0.5317
# Evaluation: embeddings 5, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 634us/step
# [Kmeans, DAE] Silhouette: 0.5496
# Evaluation: embeddings 6, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.5943
# Evaluation: embeddings 6, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.4893
# Evaluation: embeddings 6, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.6017
# Evaluation: embeddings 6, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 611us/step
# [Kmeans, DAE] Silhouette: 0.5413
# Evaluation: embeddings 6, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 646us/step
# [Kmeans, DAE] Silhouette: 0.5380
# Evaluation: embeddings 6, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 619us/step
# [Kmeans, DAE] Silhouette: 0.4652
# Evaluation: embeddings 6, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.5406
# Evaluation: embeddings 6, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 584us/step
# [Kmeans, DAE] Silhouette: 0.5716
# Evaluation: embeddings 6, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 553us/step
# [Kmeans, DAE] Silhouette: 0.5281
# Evaluation: embeddings 6, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 562us/step
# [Kmeans, DAE] Silhouette: 0.5408
# Evaluation: embeddings 6, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.5333
# Evaluation: embeddings 6, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.5276
# Evaluation: embeddings 6, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 583us/step
# [Kmeans, DAE] Silhouette: 0.5427
# Evaluation: embeddings 6, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 633us/step
# [Kmeans, DAE] Silhouette: 0.4806
# Evaluation: embeddings 6, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# [Kmeans, DAE] Silhouette: 0.4998
# Evaluation: embeddings 6, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 682us/step
# [Kmeans, DAE] Silhouette: 0.5923
# Evaluation: embeddings 6, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 607us/step
# [Kmeans, DAE] Silhouette: 0.6031
# Evaluation: embeddings 6, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 593us/step
# [Kmeans, DAE] Silhouette: 0.5271
# Evaluation: embeddings 6, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 565us/step
# [Kmeans, DAE] Silhouette: 0.5161
# Evaluation: embeddings 6, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 608us/step
# [Kmeans, DAE] Silhouette: 0.5688
# Evaluation: embeddings 6, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 617us/step
# [Kmeans, DAE] Silhouette: 0.5596
# Evaluation: embeddings 6, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 572us/step
# [Kmeans, DAE] Silhouette: 0.5514
# Evaluation: embeddings 6, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 572us/step
# [Kmeans, DAE] Silhouette: 0.5049
# Evaluation: embeddings 6, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 569us/step
# [Kmeans, DAE] Silhouette: 0.5863
# Evaluation: embeddings 6, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 565us/step
# [Kmeans, DAE] Silhouette: 0.5477
# Evaluation: embeddings 6, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 604us/step
# [Kmeans, DAE] Silhouette: 0.5232
# Evaluation: embeddings 6, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 636us/step
# [Kmeans, DAE] Silhouette: 0.5374
# Evaluation: embeddings 6, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 619us/step
# [Kmeans, DAE] Silhouette: 0.5473
# Evaluation: embeddings 6, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.5501
# Evaluation: embeddings 6, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 660us/step
# [Kmeans, DAE] Silhouette: 0.5364
# Evaluation: embeddings 6, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 666us/step
# [Kmeans, DAE] Silhouette: 0.6116
# Evaluation: embeddings 6, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.5318
# Evaluation: embeddings 6, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 592us/step
# [Kmeans, DAE] Silhouette: 0.5481
# Evaluation: embeddings 6, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 635us/step
# [Kmeans, DAE] Silhouette: 0.4963
# Evaluation: embeddings 6, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 624us/step
# [Kmeans, DAE] Silhouette: 0.5054
# Evaluation: embeddings 7, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.6391
# Evaluation: embeddings 7, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5074
# Evaluation: embeddings 7, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 627us/step
# [Kmeans, DAE] Silhouette: 0.5229
# Evaluation: embeddings 7, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.5488
# Evaluation: embeddings 7, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 643us/step
# [Kmeans, DAE] Silhouette: 0.5341
# Evaluation: embeddings 7, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.5312
# Evaluation: embeddings 7, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# [Kmeans, DAE] Silhouette: 0.5362
# Evaluation: embeddings 7, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# [Kmeans, DAE] Silhouette: 0.5614
# Evaluation: embeddings 7, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.5282
# Evaluation: embeddings 7, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 637us/step
# [Kmeans, DAE] Silhouette: 0.5148
# Evaluation: embeddings 7, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 627us/step
# [Kmeans, DAE] Silhouette: 0.5370
# Evaluation: embeddings 7, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 614us/step
# [Kmeans, DAE] Silhouette: 0.4914
# Evaluation: embeddings 7, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.5114
# Evaluation: embeddings 7, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 626us/step
# [Kmeans, DAE] Silhouette: 0.4937
# Evaluation: embeddings 7, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 623us/step
# [Kmeans, DAE] Silhouette: 0.5294
# Evaluation: embeddings 7, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 642us/step
# [Kmeans, DAE] Silhouette: 0.5104
# Evaluation: embeddings 7, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.5390
# Evaluation: embeddings 7, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 616us/step
# [Kmeans, DAE] Silhouette: 0.5366
# Evaluation: embeddings 7, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 610us/step
# [Kmeans, DAE] Silhouette: 0.5308
# Evaluation: embeddings 7, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 638us/step
# [Kmeans, DAE] Silhouette: 0.5382
# Evaluation: embeddings 7, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 637us/step
# [Kmeans, DAE] Silhouette: 0.5549
# Evaluation: embeddings 7, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 626us/step
# [Kmeans, DAE] Silhouette: 0.5356
# Evaluation: embeddings 7, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.5709
# Evaluation: embeddings 7, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.5407
# Evaluation: embeddings 7, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 638us/step
# [Kmeans, DAE] Silhouette: 0.4772
# Evaluation: embeddings 7, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 601us/step
# [Kmeans, DAE] Silhouette: 0.5317
# Evaluation: embeddings 7, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 777us/step
# [Kmeans, DAE] Silhouette: 0.5579
# Evaluation: embeddings 7, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 683us/step
# [Kmeans, DAE] Silhouette: 0.5677
# Evaluation: embeddings 7, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 653us/step
# [Kmeans, DAE] Silhouette: 0.5653
# Evaluation: embeddings 7, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 670us/step
# [Kmeans, DAE] Silhouette: 0.6183
# Evaluation: embeddings 7, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step
# [Kmeans, DAE] Silhouette: 0.5313
# Evaluation: embeddings 7, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 659us/step
# [Kmeans, DAE] Silhouette: 0.6263
# Evaluation: embeddings 7, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step
# [Kmeans, DAE] Silhouette: 0.5471
# Evaluation: embeddings 7, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 685us/step
# [Kmeans, DAE] Silhouette: 0.5313
# Evaluation: embeddings 7, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 668us/step
# [Kmeans, DAE] Silhouette: 0.5339
# Evaluation: embeddings 8, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 670us/step
# [Kmeans, DAE] Silhouette: 0.5086
# Evaluation: embeddings 8, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 585us/step
# [Kmeans, DAE] Silhouette: 0.5380
# Evaluation: embeddings 8, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 569us/step
# [Kmeans, DAE] Silhouette: 0.4986
# Evaluation: embeddings 8, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step
# [Kmeans, DAE] Silhouette: 0.5240
# Evaluation: embeddings 8, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.5770
# Evaluation: embeddings 8, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 663us/step
# [Kmeans, DAE] Silhouette: 0.5235
# Evaluation: embeddings 8, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 646us/step
# [Kmeans, DAE] Silhouette: 0.5624
# Evaluation: embeddings 8, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 615us/step
# [Kmeans, DAE] Silhouette: 0.5931
# Evaluation: embeddings 8, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 628us/step
# [Kmeans, DAE] Silhouette: 0.5564
# Evaluation: embeddings 8, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 607us/step
# [Kmeans, DAE] Silhouette: 0.5083
# Evaluation: embeddings 8, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 578us/step
# [Kmeans, DAE] Silhouette: 0.5424
# Evaluation: embeddings 8, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 596us/step
# [Kmeans, DAE] Silhouette: 0.5305
# Evaluation: embeddings 8, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.5559
# Evaluation: embeddings 8, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 601us/step
# [Kmeans, DAE] Silhouette: 0.5287
# Evaluation: embeddings 8, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 605us/step
# [Kmeans, DAE] Silhouette: 0.6158
# Evaluation: embeddings 8, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5341
# Evaluation: embeddings 8, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 626us/step
# [Kmeans, DAE] Silhouette: 0.6328
# Evaluation: embeddings 8, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 644us/step
# [Kmeans, DAE] Silhouette: 0.5524
# Evaluation: embeddings 8, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.5659
# Evaluation: embeddings 8, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 562us/step
# [Kmeans, DAE] Silhouette: 0.5487
# Evaluation: embeddings 8, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.4776
# Evaluation: embeddings 8, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 570us/step
# [Kmeans, DAE] Silhouette: 0.5396
# Evaluation: embeddings 8, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 583us/step
# [Kmeans, DAE] Silhouette: 0.5287
# Evaluation: embeddings 8, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5354
# Evaluation: embeddings 8, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 614us/step
# [Kmeans, DAE] Silhouette: 0.5098
# Evaluation: embeddings 8, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 605us/step
# [Kmeans, DAE] Silhouette: 0.5299
# Evaluation: embeddings 8, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 646us/step
# [Kmeans, DAE] Silhouette: 0.5362
# Evaluation: embeddings 8, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 629us/step
# [Kmeans, DAE] Silhouette: 0.6313
# Evaluation: embeddings 8, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 675us/step
# [Kmeans, DAE] Silhouette: 0.5398
# Evaluation: embeddings 8, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 644us/step
# [Kmeans, DAE] Silhouette: 0.5457
# Evaluation: embeddings 8, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 642us/step
# [Kmeans, DAE] Silhouette: 0.5522
# Evaluation: embeddings 8, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 634us/step
# [Kmeans, DAE] Silhouette: 0.5509
# Evaluation: embeddings 8, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 613us/step
# [Kmeans, DAE] Silhouette: 0.5610
# Evaluation: embeddings 8, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 595us/step
# [Kmeans, DAE] Silhouette: 0.4911
# Evaluation: embeddings 8, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 590us/step
# [Kmeans, DAE] Silhouette: 0.5458
# Evaluation: embeddings 9, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 623us/step
# [Kmeans, DAE] Silhouette: 0.5447
# Evaluation: embeddings 9, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 580us/step
# [Kmeans, DAE] Silhouette: 0.5617
# Evaluation: embeddings 9, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 616us/step
# [Kmeans, DAE] Silhouette: 0.5722
# Evaluation: embeddings 9, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.5478
# Evaluation: embeddings 9, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 649us/step
# [Kmeans, DAE] Silhouette: 0.5458
# Evaluation: embeddings 9, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 571us/step
# [Kmeans, DAE] Silhouette: 0.4872
# Evaluation: embeddings 9, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 595us/step
# [Kmeans, DAE] Silhouette: 0.5416
# Evaluation: embeddings 9, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 607us/step
# [Kmeans, DAE] Silhouette: 0.5551
# Evaluation: embeddings 9, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.5783
# Evaluation: embeddings 9, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 578us/step
# [Kmeans, DAE] Silhouette: 0.5101
# Evaluation: embeddings 9, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 601us/step
# [Kmeans, DAE] Silhouette: 0.5854
# Evaluation: embeddings 9, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.5137
# Evaluation: embeddings 9, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 591us/step
# [Kmeans, DAE] Silhouette: 0.4924
# Evaluation: embeddings 9, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step
# [Kmeans, DAE] Silhouette: 0.5267
# Evaluation: embeddings 9, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 633us/step
# [Kmeans, DAE] Silhouette: 0.5356
# Evaluation: embeddings 9, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 634us/step
# [Kmeans, DAE] Silhouette: 0.5821
# Evaluation: embeddings 9, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 615us/step
# [Kmeans, DAE] Silhouette: 0.5116
# Evaluation: embeddings 9, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.4856
# Evaluation: embeddings 9, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 598us/step
# [Kmeans, DAE] Silhouette: 0.5401
# Evaluation: embeddings 9, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 623us/step
# [Kmeans, DAE] Silhouette: 0.5301
# Evaluation: embeddings 9, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 644us/step
# [Kmeans, DAE] Silhouette: 0.5286
# Evaluation: embeddings 9, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 613us/step
# [Kmeans, DAE] Silhouette: 0.5361
# Evaluation: embeddings 9, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 600us/step
# [Kmeans, DAE] Silhouette: 0.5154
# Evaluation: embeddings 9, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 644us/step
# [Kmeans, DAE] Silhouette: 0.5561
# Evaluation: embeddings 9, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 646us/step
# [Kmeans, DAE] Silhouette: 0.5612
# Evaluation: embeddings 9, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 656us/step
# [Kmeans, DAE] Silhouette: 0.5526
# Evaluation: embeddings 9, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 659us/step
# [Kmeans, DAE] Silhouette: 0.5092
# Evaluation: embeddings 9, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 663us/step
# [Kmeans, DAE] Silhouette: 0.5190
# Evaluation: embeddings 9, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 572us/step
# [Kmeans, DAE] Silhouette: 0.5502
# Evaluation: embeddings 9, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.5413
# Evaluation: embeddings 9, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 568us/step
# [Kmeans, DAE] Silhouette: 0.5491
# Evaluation: embeddings 9, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 606us/step
# [Kmeans, DAE] Silhouette: 0.5581
# Evaluation: embeddings 9, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 594us/step
# [Kmeans, DAE] Silhouette: 0.5555
# Evaluation: embeddings 9, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.5613
# Evaluation: embeddings 9, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.5343
# Silhouette: 0.6695
# Best parameters: 5_2_2048_linear

# %%
hypertune(1, 8)
# Out:
# Evaluation: embeddings 3, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 637us/step
# [Kmeans, DAE] Silhouette: 0.7109
# Evaluation: embeddings 3, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step
# [Kmeans, DAE] Silhouette: 0.7276
# Evaluation: embeddings 3, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step
# [Kmeans, DAE] Silhouette: 0.6722
# Evaluation: embeddings 3, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step
# [Kmeans, DAE] Silhouette: 0.7475
# Evaluation: embeddings 3, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 626us/step
# [Kmeans, DAE] Silhouette: 0.6535
# Evaluation: embeddings 3, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step
# [Kmeans, DAE] Silhouette: 0.6453
# Evaluation: embeddings 3, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step
# [Kmeans, DAE] Silhouette: 0.6304
# Evaluation: embeddings 3, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# [Kmeans, DAE] Silhouette: 0.6054
# Evaluation: embeddings 3, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step
# [Kmeans, DAE] Silhouette: 0.6894
# Evaluation: embeddings 3, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 876us/step
# [Kmeans, DAE] Silhouette: 0.7209
# Evaluation: embeddings 3, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 862us/step
# [Kmeans, DAE] Silhouette: 0.7661
# Evaluation: embeddings 3, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 831us/step
# [Kmeans, DAE] Silhouette: 0.6064
# Evaluation: embeddings 3, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 869us/step
# [Kmeans, DAE] Silhouette: 0.7437
# Evaluation: embeddings 3, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 804us/step
# [Kmeans, DAE] Silhouette: 0.6242
# Evaluation: embeddings 3, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 810us/step
# [Kmeans, DAE] Silhouette: 0.6233
# Evaluation: embeddings 3, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 625us/step
# [Kmeans, DAE] Silhouette: 0.7243
# Evaluation: embeddings 3, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 613us/step
# [Kmeans, DAE] Silhouette: 0.7889
# Evaluation: embeddings 3, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 624us/step
# [Kmeans, DAE] Silhouette: 0.5924
# Evaluation: embeddings 3, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 632us/step
# [Kmeans, DAE] Silhouette: 0.6075
# Evaluation: embeddings 3, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 618us/step
# [Kmeans, DAE] Silhouette: 0.6138
# Evaluation: embeddings 3, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 639us/step
# [Kmeans, DAE] Silhouette: 0.7289
# Evaluation: embeddings 3, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 647us/step
# [Kmeans, DAE] Silhouette: 0.5839
# Evaluation: embeddings 3, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step
# [Kmeans, DAE] Silhouette: 0.6351
# Evaluation: embeddings 3, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 617us/step
# [Kmeans, DAE] Silhouette: 0.7927
# Evaluation: embeddings 3, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 620us/step
# [Kmeans, DAE] Silhouette: 0.5966
# Evaluation: embeddings 3, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 630us/step
# [Kmeans, DAE] Silhouette: 0.6851
# Evaluation: embeddings 3, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 654us/step
# [Kmeans, DAE] Silhouette: 0.5599
# Evaluation: embeddings 3, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 667us/step
# [Kmeans, DAE] Silhouette: 0.5906
# Evaluation: embeddings 3, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 688us/step
# [Kmeans, DAE] Silhouette: 0.6061
# Evaluation: embeddings 3, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step
# [Kmeans, DAE] Silhouette: 0.7340
# Evaluation: embeddings 3, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step
# [Kmeans, DAE] Silhouette: 0.6338
# Evaluation: embeddings 3, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 660us/step
# [Kmeans, DAE] Silhouette: 0.6392
# Evaluation: embeddings 3, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 643us/step
# [Kmeans, DAE] Silhouette: 0.6501
# Evaluation: embeddings 3, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step
# [Kmeans, DAE] Silhouette: 0.5763
# Evaluation: embeddings 3, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 620us/step
# [Kmeans, DAE] Silhouette: 0.6253
# Evaluation: embeddings 4, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 629us/step
# [Kmeans, DAE] Silhouette: 0.7154
# Evaluation: embeddings 4, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step
# [Kmeans, DAE] Silhouette: 0.7547
# Evaluation: embeddings 4, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 610us/step
# [Kmeans, DAE] Silhouette: 0.7393
# Evaluation: embeddings 4, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 602us/step
# [Kmeans, DAE] Silhouette: 0.6164
# Evaluation: embeddings 4, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step
# [Kmeans, DAE] Silhouette: 0.7608
# Evaluation: embeddings 4, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step
# [Kmeans, DAE] Silhouette: 0.6534
# Evaluation: embeddings 4, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step
# [Kmeans, DAE] Silhouette: 0.6227
# Evaluation: embeddings 4, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step
# [Kmeans, DAE] Silhouette: 0.7341
# Evaluation: embeddings 4, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 684us/step
# [Kmeans, DAE] Silhouette: 0.7150
# Evaluation: embeddings 4, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step
# [Kmeans, DAE] Silhouette: 0.7272
# Evaluation: embeddings 4, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step
# [Kmeans, DAE] Silhouette: 0.7376
# Evaluation: embeddings 4, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 705us/step
# [Kmeans, DAE] Silhouette: 0.6280
# Evaluation: embeddings 4, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 669us/step
# [Kmeans, DAE] Silhouette: 0.5995
# Evaluation: embeddings 4, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step
# [Kmeans, DAE] Silhouette: 0.5939
# Evaluation: embeddings 4, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step
# [Kmeans, DAE] Silhouette: 0.7585
# Evaluation: embeddings 4, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step
# [Kmeans, DAE] Silhouette: 0.5954
# Evaluation: embeddings 4, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step
# [Kmeans, DAE] Silhouette: 0.6360
# Evaluation: embeddings 4, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step
# [Kmeans, DAE] Silhouette: 0.6092
# Evaluation: embeddings 4, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 723us/step
# [Kmeans, DAE] Silhouette: 0.6168
# Evaluation: embeddings 4, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step
# [Kmeans, DAE] Silhouette: 0.6833
# Evaluation: embeddings 4, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
# [Kmeans, DAE] Silhouette: 0.5685
# Evaluation: embeddings 4, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 669us/step
# [Kmeans, DAE] Silhouette: 0.6103
# Evaluation: embeddings 4, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step
# [Kmeans, DAE] Silhouette: 0.6112
# Evaluation: embeddings 4, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step
# [Kmeans, DAE] Silhouette: 0.6269
# Evaluation: embeddings 4, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step
# [Kmeans, DAE] Silhouette: 0.6220
# Evaluation: embeddings 4, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step
# [Kmeans, DAE] Silhouette: 0.5772
# Evaluation: embeddings 4, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 737us/step
# [Kmeans, DAE] Silhouette: 0.5879
# Evaluation: embeddings 4, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step
# [Kmeans, DAE] Silhouette: 0.5932
# Evaluation: embeddings 4, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step
# [Kmeans, DAE] Silhouette: 0.5814
# Evaluation: embeddings 4, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 702us/step
# [Kmeans, DAE] Silhouette: 0.5855
# Evaluation: embeddings 4, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step
# [Kmeans, DAE] Silhouette: 0.5971
# Evaluation: embeddings 4, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step
# [Kmeans, DAE] Silhouette: 0.6370
# Evaluation: embeddings 4, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step
# [Kmeans, DAE] Silhouette: 0.6398
# Evaluation: embeddings 4, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step
# [Kmeans, DAE] Silhouette: 0.5836
# Evaluation: embeddings 4, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 704us/step
# [Kmeans, DAE] Silhouette: 0.6268
# Evaluation: embeddings 5, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step
# [Kmeans, DAE] Silhouette: 0.7776
# Evaluation: embeddings 5, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step
# [Kmeans, DAE] Silhouette: 0.7073
# Evaluation: embeddings 5, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 877us/step
# [Kmeans, DAE] Silhouette: 0.7536
# Evaluation: embeddings 5, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step
# [Kmeans, DAE] Silhouette: 0.7606
# Evaluation: embeddings 5, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step
# [Kmeans, DAE] Silhouette: 0.7488
# Evaluation: embeddings 5, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step
# [Kmeans, DAE] Silhouette: 0.5995
# Evaluation: embeddings 5, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step
# [Kmeans, DAE] Silhouette: 0.7569
# Evaluation: embeddings 5, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step
# [Kmeans, DAE] Silhouette: 0.8213
# Evaluation: embeddings 5, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step
# [Kmeans, DAE] Silhouette: 0.6361
# Evaluation: embeddings 5, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 707us/step
# [Kmeans, DAE] Silhouette: 0.7383
# Evaluation: embeddings 5, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 705us/step
# [Kmeans, DAE] Silhouette: 0.6162
# Evaluation: embeddings 5, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step
# [Kmeans, DAE] Silhouette: 0.7247
# Evaluation: embeddings 5, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 757us/step
# [Kmeans, DAE] Silhouette: 0.5728
# Evaluation: embeddings 5, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 699us/step
# [Kmeans, DAE] Silhouette: 0.5968
# Evaluation: embeddings 5, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step
# [Kmeans, DAE] Silhouette: 0.6258
# Evaluation: embeddings 5, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step
# [Kmeans, DAE] Silhouette: 0.6030
# Evaluation: embeddings 5, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step
# [Kmeans, DAE] Silhouette: 0.6397
# Evaluation: embeddings 5, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step
# [Kmeans, DAE] Silhouette: 0.5667
# Evaluation: embeddings 5, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 892us/step
# [Kmeans, DAE] Silhouette: 0.6124
# Evaluation: embeddings 5, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 671us/step
# [Kmeans, DAE] Silhouette: 0.6109
# Evaluation: embeddings 5, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step
# [Kmeans, DAE] Silhouette: 0.7105
# Evaluation: embeddings 5, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step
# [Kmeans, DAE] Silhouette: 0.6126
# Evaluation: embeddings 5, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 12s 615us/step
# [Kmeans, DAE] Silhouette: 0.5832
# Evaluation: embeddings 5, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 613us/step
# [Kmeans, DAE] Silhouette: 0.6547
# Evaluation: embeddings 5, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 603us/step
# [Kmeans, DAE] Silhouette: 0.6085
# Evaluation: embeddings 5, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 622us/step
# [Kmeans, DAE] Silhouette: 0.6720
# Evaluation: embeddings 5, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step
# [Kmeans, DAE] Silhouette: 0.5829
# Evaluation: embeddings 5, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step
# [Kmeans, DAE] Silhouette: 0.5783
# Evaluation: embeddings 5, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 705us/step
# [Kmeans, DAE] Silhouette: 0.6155
# Evaluation: embeddings 5, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step
# [Kmeans, DAE] Silhouette: 0.5979
# Evaluation: embeddings 5, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step
# [Kmeans, DAE] Silhouette: 0.6194
# Evaluation: embeddings 5, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step
# [Kmeans, DAE] Silhouette: 0.5955
# Evaluation: embeddings 5, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 633us/step
# [Kmeans, DAE] Silhouette: 0.5892
# Evaluation: embeddings 5, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 641us/step
# [Kmeans, DAE] Silhouette: 0.6110
# Evaluation: embeddings 5, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 629us/step
# [Kmeans, DAE] Silhouette: 0.6013
# Evaluation: embeddings 6, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step
# [Kmeans, DAE] Silhouette: 0.5105
# Evaluation: embeddings 6, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# [Kmeans, DAE] Silhouette: 0.5974
# Evaluation: embeddings 6, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step
# [Kmeans, DAE] Silhouette: 0.6068
# Evaluation: embeddings 6, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step
# [Kmeans, DAE] Silhouette: 0.6200
# Evaluation: embeddings 6, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step
# [Kmeans, DAE] Silhouette: 0.5773
# Evaluation: embeddings 6, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step
# [Kmeans, DAE] Silhouette: 0.6297
# Evaluation: embeddings 6, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 629us/step
# [Kmeans, DAE] Silhouette: 0.6224
# Evaluation: embeddings 6, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 713us/step
# [Kmeans, DAE] Silhouette: 0.6415
# Evaluation: embeddings 6, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 667us/step
# [Kmeans, DAE] Silhouette: 0.6124
# Evaluation: embeddings 6, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step
# [Kmeans, DAE] Silhouette: 0.5885
# Evaluation: embeddings 6, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 646us/step
# [Kmeans, DAE] Silhouette: 0.6444
# Evaluation: embeddings 6, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step
# [Kmeans, DAE] Silhouette: 0.5493
# Evaluation: embeddings 6, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step
# [Kmeans, DAE] Silhouette: 0.6407
# Evaluation: embeddings 6, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 624us/step
# [Kmeans, DAE] Silhouette: 0.6183
# Evaluation: embeddings 6, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step
# [Kmeans, DAE] Silhouette: 0.6343
# Evaluation: embeddings 6, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 617us/step
# [Kmeans, DAE] Silhouette: 0.5859
# Evaluation: embeddings 6, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 630us/step
# [Kmeans, DAE] Silhouette: 0.5942
# Evaluation: embeddings 6, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 638us/step
# [Kmeans, DAE] Silhouette: 0.6261
# Evaluation: embeddings 6, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 698us/step
# [Kmeans, DAE] Silhouette: 0.7079
# Evaluation: embeddings 6, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# [Kmeans, DAE] Silhouette: 0.6124
# Evaluation: embeddings 6, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 635us/step
# [Kmeans, DAE] Silhouette: 0.5771
# Evaluation: embeddings 6, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 612us/step
# [Kmeans, DAE] Silhouette: 0.5445
# Evaluation: embeddings 6, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step
# [Kmeans, DAE] Silhouette: 0.5937
# Evaluation: embeddings 6, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 645us/step
# [Kmeans, DAE] Silhouette: 0.6201
# Evaluation: embeddings 6, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 645us/step
# [Kmeans, DAE] Silhouette: 0.5945
# Evaluation: embeddings 6, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 695us/step
# [Kmeans, DAE] Silhouette: 0.6064
# Evaluation: embeddings 6, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 653us/step
# [Kmeans, DAE] Silhouette: 0.6276
# Evaluation: embeddings 6, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step
# [Kmeans, DAE] Silhouette: 0.5869
# Evaluation: embeddings 6, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step
# [Kmeans, DAE] Silhouette: 0.6013
# Evaluation: embeddings 6, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step
# [Kmeans, DAE] Silhouette: 0.6506
# Evaluation: embeddings 6, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step
# [Kmeans, DAE] Silhouette: 0.5570
# Evaluation: embeddings 6, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step
# [Kmeans, DAE] Silhouette: 0.6100
# Evaluation: embeddings 6, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step
# [Kmeans, DAE] Silhouette: 0.5457
# Evaluation: embeddings 6, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step
# [Kmeans, DAE] Silhouette: 0.6031
# Evaluation: embeddings 6, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step
# [Kmeans, DAE] Silhouette: 0.6548
# Evaluation: embeddings 7, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step
# [Kmeans, DAE] Silhouette: 0.6108
# Evaluation: embeddings 7, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step
# [Kmeans, DAE] Silhouette: 0.6569
# Evaluation: embeddings 7, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step
# [Kmeans, DAE] Silhouette: 0.6030
# Evaluation: embeddings 7, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step
# [Kmeans, DAE] Silhouette: 0.6267
# Evaluation: embeddings 7, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 689us/step
# [Kmeans, DAE] Silhouette: 0.6957
# Evaluation: embeddings 7, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 666us/step
# [Kmeans, DAE] Silhouette: 0.6229
# Evaluation: embeddings 7, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 662us/step
# [Kmeans, DAE] Silhouette: 0.6426
# Evaluation: embeddings 7, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 749us/step
# [Kmeans, DAE] Silhouette: 0.5897
# Evaluation: embeddings 7, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step
# [Kmeans, DAE] Silhouette: 0.6835
# Evaluation: embeddings 7, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 701us/step
# [Kmeans, DAE] Silhouette: 0.6259
# Evaluation: embeddings 7, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step
# [Kmeans, DAE] Silhouette: 0.5977
# Evaluation: embeddings 7, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step
# [Kmeans, DAE] Silhouette: 0.6095
# Evaluation: embeddings 7, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 652us/step
# [Kmeans, DAE] Silhouette: 0.6286
# Evaluation: embeddings 7, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 669us/step
# [Kmeans, DAE] Silhouette: 0.5963
# Evaluation: embeddings 7, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step
# [Kmeans, DAE] Silhouette: 0.5930
# Evaluation: embeddings 7, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 691us/step
# [Kmeans, DAE] Silhouette: 0.6003
# Evaluation: embeddings 7, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step
# [Kmeans, DAE] Silhouette: 0.5892
# Evaluation: embeddings 7, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step
# [Kmeans, DAE] Silhouette: 0.5807
# Evaluation: embeddings 7, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 686us/step
# [Kmeans, DAE] Silhouette: 0.6217
# Evaluation: embeddings 7, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 705us/step
# [Kmeans, DAE] Silhouette: 0.6066
# Evaluation: embeddings 7, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# [Kmeans, DAE] Silhouette: 0.6360
# Evaluation: embeddings 7, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 694us/step
# [Kmeans, DAE] Silhouette: 0.6124
# Evaluation: embeddings 7, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step
# [Kmeans, DAE] Silhouette: 0.6172
# Evaluation: embeddings 7, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step
# [Kmeans, DAE] Silhouette: 0.5718
# Evaluation: embeddings 7, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step
# [Kmeans, DAE] Silhouette: 0.6127
# Evaluation: embeddings 7, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step
# [Kmeans, DAE] Silhouette: 0.5974
# Evaluation: embeddings 7, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# [Kmeans, DAE] Silhouette: 0.5991
# Evaluation: embeddings 7, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 664us/step
# [Kmeans, DAE] Silhouette: 0.5986
# Evaluation: embeddings 7, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 667us/step
# [Kmeans, DAE] Silhouette: 0.5895
# Evaluation: embeddings 7, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step
# [Kmeans, DAE] Silhouette: 0.6312
# Evaluation: embeddings 7, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step
# [Kmeans, DAE] Silhouette: 0.5996
# Evaluation: embeddings 7, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 806us/step
# [Kmeans, DAE] Silhouette: 0.5873
# Evaluation: embeddings 7, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 764us/step
# [Kmeans, DAE] Silhouette: 0.5920
# Evaluation: embeddings 7, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step
# [Kmeans, DAE] Silhouette: 0.5680
# Evaluation: embeddings 7, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step
# [Kmeans, DAE] Silhouette: 0.5878
# Evaluation: embeddings 8, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 714us/step
# [Kmeans, DAE] Silhouette: 0.5573
# Evaluation: embeddings 8, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 726us/step
# [Kmeans, DAE] Silhouette: 0.6098
# Evaluation: embeddings 8, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 715us/step
# [Kmeans, DAE] Silhouette: 0.6325
# Evaluation: embeddings 8, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step
# [Kmeans, DAE] Silhouette: 0.6177
# Evaluation: embeddings 8, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step
# [Kmeans, DAE] Silhouette: 0.5889
# Evaluation: embeddings 8, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 699us/step
# [Kmeans, DAE] Silhouette: 0.6192
# Evaluation: embeddings 8, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step
# [Kmeans, DAE] Silhouette: 0.6432
# Evaluation: embeddings 8, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step
# [Kmeans, DAE] Silhouette: 0.5946
# Evaluation: embeddings 8, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 697us/step
# [Kmeans, DAE] Silhouette: 0.6081
# Evaluation: embeddings 8, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 633us/step
# [Kmeans, DAE] Silhouette: 0.6139
# Evaluation: embeddings 8, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 638us/step
# [Kmeans, DAE] Silhouette: 0.6160
# Evaluation: embeddings 8, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step
# [Kmeans, DAE] Silhouette: 0.7305
# Evaluation: embeddings 8, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step
# [Kmeans, DAE] Silhouette: 0.5983
# Evaluation: embeddings 8, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step
# [Kmeans, DAE] Silhouette: 0.5961
# Evaluation: embeddings 8, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step
# [Kmeans, DAE] Silhouette: 0.6144
# Evaluation: embeddings 8, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step
# [Kmeans, DAE] Silhouette: 0.6159
# Evaluation: embeddings 8, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 721us/step
# [Kmeans, DAE] Silhouette: 0.6472
# Evaluation: embeddings 8, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step
# [Kmeans, DAE] Silhouette: 0.6032
# Evaluation: embeddings 8, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step
# [Kmeans, DAE] Silhouette: 0.5827
# Evaluation: embeddings 8, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 749us/step
# [Kmeans, DAE] Silhouette: 0.6239
# Evaluation: embeddings 8, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 741us/step
# [Kmeans, DAE] Silhouette: 0.6252
# Evaluation: embeddings 8, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
# [Kmeans, DAE] Silhouette: 0.5583
# Evaluation: embeddings 8, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 756us/step
# [Kmeans, DAE] Silhouette: 0.5971
# Evaluation: embeddings 8, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step
# [Kmeans, DAE] Silhouette: 0.6073
# Evaluation: embeddings 8, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step
# [Kmeans, DAE] Silhouette: 0.6061
# Evaluation: embeddings 8, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step
# [Kmeans, DAE] Silhouette: 0.6116
# Evaluation: embeddings 8, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step
# [Kmeans, DAE] Silhouette: 0.5752
# Evaluation: embeddings 8, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step
# [Kmeans, DAE] Silhouette: 0.5920
# Evaluation: embeddings 8, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 671us/step
# [Kmeans, DAE] Silhouette: 0.5984
# Evaluation: embeddings 8, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 690us/step
# [Kmeans, DAE] Silhouette: 0.6214
# Evaluation: embeddings 8, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 717us/step
# [Kmeans, DAE] Silhouette: 0.5973
# Evaluation: embeddings 8, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step
# [Kmeans, DAE] Silhouette: 0.6107
# Evaluation: embeddings 8, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 696us/step
# [Kmeans, DAE] Silhouette: 0.5819
# Evaluation: embeddings 8, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step
# [Kmeans, DAE] Silhouette: 0.6064
# Evaluation: embeddings 8, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step
# [Kmeans, DAE] Silhouette: 0.6193
# Evaluation: embeddings 9, epoch 2, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# [Kmeans, DAE] Silhouette: 0.6279
# Evaluation: embeddings 9, epoch 2, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 923us/step
# [Kmeans, DAE] Silhouette: 0.6018
# Evaluation: embeddings 9, epoch 2, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 687us/step
# [Kmeans, DAE] Silhouette: 0.6103
# Evaluation: embeddings 9, epoch 2, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 931us/step
# [Kmeans, DAE] Silhouette: 0.6596
# Evaluation: embeddings 9, epoch 2, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 851us/step
# [Kmeans, DAE] Silhouette: 0.8112
# Evaluation: embeddings 9, epoch 3, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step
# [Kmeans, DAE] Silhouette: 0.6082
# Evaluation: embeddings 9, epoch 3, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step
# [Kmeans, DAE] Silhouette: 0.5818
# Evaluation: embeddings 9, epoch 3, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step
# [Kmeans, DAE] Silhouette: 0.6929
# Evaluation: embeddings 9, epoch 3, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step
# [Kmeans, DAE] Silhouette: 0.6000
# Evaluation: embeddings 9, epoch 3, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 952us/step
# [Kmeans, DAE] Silhouette: 0.6118
# Evaluation: embeddings 9, epoch 4, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step
# [Kmeans, DAE] Silhouette: 0.6171
# Evaluation: embeddings 9, epoch 4, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step
# [Kmeans, DAE] Silhouette: 0.5992
# Evaluation: embeddings 9, epoch 4, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 756us/step
# [Kmeans, DAE] Silhouette: 0.6426
# Evaluation: embeddings 9, epoch 4, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step
# [Kmeans, DAE] Silhouette: 0.6423
# Evaluation: embeddings 9, epoch 4, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step
# [Kmeans, DAE] Silhouette: 0.6792
# Evaluation: embeddings 9, epoch 5, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step
# [Kmeans, DAE] Silhouette: 0.6341
# Evaluation: embeddings 9, epoch 5, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step
# [Kmeans, DAE] Silhouette: 0.5769
# Evaluation: embeddings 9, epoch 5, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step
# [Kmeans, DAE] Silhouette: 0.5824
# Evaluation: embeddings 9, epoch 5, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 685us/step
# [Kmeans, DAE] Silhouette: 0.5933
# Evaluation: embeddings 9, epoch 5, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step
# [Kmeans, DAE] Silhouette: 0.6251
# Evaluation: embeddings 9, epoch 6, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
# [Kmeans, DAE] Silhouette: 0.5952
# Evaluation: embeddings 9, epoch 6, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step
# [Kmeans, DAE] Silhouette: 0.6093
# Evaluation: embeddings 9, epoch 6, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 797us/step
# [Kmeans, DAE] Silhouette: 0.6137
# Evaluation: embeddings 9, epoch 6, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 923us/step
# [Kmeans, DAE] Silhouette: 0.5906
# Evaluation: embeddings 9, epoch 6, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 900us/step
# [Kmeans, DAE] Silhouette: 0.5923
# Evaluation: embeddings 9, epoch 7, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 914us/step
# [Kmeans, DAE] Silhouette: 0.5838
# Evaluation: embeddings 9, epoch 7, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 852us/step
# [Kmeans, DAE] Silhouette: 0.6315
# Evaluation: embeddings 9, epoch 7, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 909us/step
# [Kmeans, DAE] Silhouette: 0.5935
# Evaluation: embeddings 9, epoch 7, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# [Kmeans, DAE] Silhouette: 0.6187
# Evaluation: embeddings 9, epoch 7, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 2s 947us/step
# [Kmeans, DAE] Silhouette: 0.5875
# Evaluation: embeddings 9, epoch 8, eval # 1:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 849us/step
# [Kmeans, DAE] Silhouette: 0.5894
# Evaluation: embeddings 9, epoch 8, eval # 2:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 852us/step
# [Kmeans, DAE] Silhouette: 0.5935
# Evaluation: embeddings 9, epoch 8, eval # 3:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 874us/step
# [Kmeans, DAE] Silhouette: 0.5821
# Evaluation: embeddings 9, epoch 8, eval # 4:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step
# [Kmeans, DAE] Silhouette: 0.6038
# Evaluation: embeddings 9, epoch 8, eval # 5:
# 1574/1574 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step
# [Kmeans, DAE] Silhouette: 0.6120
# Silhouette: 0.8213
# Best parameters: 5_3_2048_linear

# %%
hypertune(2, 4)
# Out:
# WARNING:tensorflow:From C:\Users\met48\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Evaluation: embeddings 3, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 630us/step
# C:\Users\met48\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\met48\AppData\Local\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [Kmeans, DAE] Silhouette: 0.7887
# Evaluation: embeddings 3, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.8098
# Evaluation: embeddings 3, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.7931
# Evaluation: embeddings 3, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 656us/step
# [Kmeans, DAE] Silhouette: 0.9601
# Evaluation: embeddings 3, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step
# [Kmeans, DAE] Silhouette: 0.8164
# Evaluation: embeddings 3, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 675us/step
# [Kmeans, DAE] Silhouette: 0.7567
# Evaluation: embeddings 3, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
# [Kmeans, DAE] Silhouette: 0.9307
# Evaluation: embeddings 3, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 643us/step
# [Kmeans, DAE] Silhouette: 0.7880
# Evaluation: embeddings 3, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 652us/step
# [Kmeans, DAE] Silhouette: 0.8976
# Evaluation: embeddings 3, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.9342
# Evaluation: embeddings 3, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 660us/step
# [Kmeans, DAE] Silhouette: 0.7369
# Evaluation: embeddings 3, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 594us/step
# [Kmeans, DAE] Silhouette: 0.8844
# Evaluation: embeddings 3, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step
# [Kmeans, DAE] Silhouette: 0.8141
# Evaluation: embeddings 3, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 685us/step
# [Kmeans, DAE] Silhouette: 0.9185
# Evaluation: embeddings 3, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 630us/step
# [Kmeans, DAE] Silhouette: 0.7344
# Evaluation: embeddings 3, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.8452
# Evaluation: embeddings 3, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 663us/step
# [Kmeans, DAE] Silhouette: 0.7339
# Evaluation: embeddings 3, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step
# [Kmeans, DAE] Silhouette: 0.9149
# Evaluation: embeddings 3, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 592us/step
# [Kmeans, DAE] Silhouette: 0.7721
# Evaluation: embeddings 3, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 652us/step
# [Kmeans, DAE] Silhouette: 0.9631
# Evaluation: embeddings 3, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 566us/step
# [Kmeans, DAE] Silhouette: 0.7081
# Evaluation: embeddings 3, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 708us/step
# [Kmeans, DAE] Silhouette: 0.8754
# Evaluation: embeddings 3, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 680us/step
# [Kmeans, DAE] Silhouette: 0.7390
# Evaluation: embeddings 3, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 657us/step
# [Kmeans, DAE] Silhouette: 0.7786
# Evaluation: embeddings 3, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7468
# Evaluation: embeddings 3, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 3s 809us/step
# [Kmeans, DAE] Silhouette: 0.7740
# Evaluation: embeddings 3, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step
# [Kmeans, DAE] Silhouette: 0.7513
# Evaluation: embeddings 3, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 579us/step
# [Kmeans, DAE] Silhouette: 0.9300
# Evaluation: embeddings 3, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 667us/step
# [Kmeans, DAE] Silhouette: 0.8608
# Evaluation: embeddings 3, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.7492
# Evaluation: embeddings 3, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.7444
# Evaluation: embeddings 3, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 660us/step
# [Kmeans, DAE] Silhouette: 0.7469
# Evaluation: embeddings 3, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 567us/step
# [Kmeans, DAE] Silhouette: 0.7569
# Evaluation: embeddings 3, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 560us/step
# [Kmeans, DAE] Silhouette: 0.7797
# Evaluation: embeddings 3, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 582us/step
# [Kmeans, DAE] Silhouette: 0.7415
# Evaluation: embeddings 4, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 648us/step
# [Kmeans, DAE] Silhouette: 0.8595
# Evaluation: embeddings 4, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 577us/step
# [Kmeans, DAE] Silhouette: 0.8469
# Evaluation: embeddings 4, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.8544
# Evaluation: embeddings 4, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step
# [Kmeans, DAE] Silhouette: 0.8868
# Evaluation: embeddings 4, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step
# [Kmeans, DAE] Silhouette: 0.8127
# Evaluation: embeddings 4, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 641us/step
# [Kmeans, DAE] Silhouette: 0.9164
# Evaluation: embeddings 4, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 666us/step
# [Kmeans, DAE] Silhouette: 0.8373
# Evaluation: embeddings 4, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 576us/step
# [Kmeans, DAE] Silhouette: 0.8214
# Evaluation: embeddings 4, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step
# [Kmeans, DAE] Silhouette: 0.9422
# Evaluation: embeddings 4, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 710us/step
# [Kmeans, DAE] Silhouette: 0.7960
# Evaluation: embeddings 4, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 771us/step
# [Kmeans, DAE] Silhouette: 0.7604
# Evaluation: embeddings 4, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step
# [Kmeans, DAE] Silhouette: 0.7562
# Evaluation: embeddings 4, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 675us/step
# [Kmeans, DAE] Silhouette: 0.7852
# Evaluation: embeddings 4, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 653us/step
# [Kmeans, DAE] Silhouette: 0.7965
# Evaluation: embeddings 4, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.7638
# Evaluation: embeddings 4, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.9019
# Evaluation: embeddings 4, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.7932
# Evaluation: embeddings 4, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 581us/step
# [Kmeans, DAE] Silhouette: 0.9069
# Evaluation: embeddings 4, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 641us/step
# [Kmeans, DAE] Silhouette: 0.7424
# Evaluation: embeddings 4, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 673us/step
# [Kmeans, DAE] Silhouette: 0.7471
# Evaluation: embeddings 4, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 649us/step
# [Kmeans, DAE] Silhouette: 0.7316
# Evaluation: embeddings 4, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# [Kmeans, DAE] Silhouette: 0.7443
# Evaluation: embeddings 4, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 718us/step
# [Kmeans, DAE] Silhouette: 0.7409
# Evaluation: embeddings 4, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 613us/step
# [Kmeans, DAE] Silhouette: 0.7403
# Evaluation: embeddings 4, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 584us/step
# [Kmeans, DAE] Silhouette: 0.7545
# Evaluation: embeddings 4, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# [Kmeans, DAE] Silhouette: 0.9384
# Evaluation: embeddings 4, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 741us/step
# [Kmeans, DAE] Silhouette: 0.7195
# Evaluation: embeddings 4, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7587
# Evaluation: embeddings 4, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 604us/step
# [Kmeans, DAE] Silhouette: 0.7668
# Evaluation: embeddings 4, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 586us/step
# [Kmeans, DAE] Silhouette: 0.7469
# Evaluation: embeddings 4, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 597us/step
# [Kmeans, DAE] Silhouette: 0.7463
# Evaluation: embeddings 4, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 583us/step
# [Kmeans, DAE] Silhouette: 0.7483
# Evaluation: embeddings 4, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.7471
# Evaluation: embeddings 4, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 585us/step
# [Kmeans, DAE] Silhouette: 0.7485
# Evaluation: embeddings 4, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 638us/step
# [Kmeans, DAE] Silhouette: 0.7407
# Evaluation: embeddings 5, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 632us/step
# [Kmeans, DAE] Silhouette: 0.9387
# Evaluation: embeddings 5, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 629us/step
# [Kmeans, DAE] Silhouette: 0.8701
# Evaluation: embeddings 5, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 683us/step
# [Kmeans, DAE] Silhouette: 0.9320
# Evaluation: embeddings 5, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.9474
# Evaluation: embeddings 5, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 636us/step
# [Kmeans, DAE] Silhouette: 0.8535
# Evaluation: embeddings 5, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 580us/step
# [Kmeans, DAE] Silhouette: 0.8100
# Evaluation: embeddings 5, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.7620
# Evaluation: embeddings 5, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.7606
# Evaluation: embeddings 5, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.9306
# Evaluation: embeddings 5, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7528
# Evaluation: embeddings 5, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.9213
# Evaluation: embeddings 5, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 701us/step
# [Kmeans, DAE] Silhouette: 0.7816
# Evaluation: embeddings 5, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 641us/step
# [Kmeans, DAE] Silhouette: 0.8322
# Evaluation: embeddings 5, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 646us/step
# [Kmeans, DAE] Silhouette: 0.8722
# Evaluation: embeddings 5, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 653us/step
# [Kmeans, DAE] Silhouette: 0.7612
# Evaluation: embeddings 5, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 654us/step
# [Kmeans, DAE] Silhouette: 0.7533
# Evaluation: embeddings 5, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 658us/step
# [Kmeans, DAE] Silhouette: 0.7857
# Evaluation: embeddings 5, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step
# [Kmeans, DAE] Silhouette: 0.7535
# Evaluation: embeddings 5, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 657us/step
# [Kmeans, DAE] Silhouette: 0.9158
# Evaluation: embeddings 5, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 666us/step
# [Kmeans, DAE] Silhouette: 0.7791
# Evaluation: embeddings 5, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.7435
# Evaluation: embeddings 5, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step
# [Kmeans, DAE] Silhouette: 0.7672
# Evaluation: embeddings 5, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 707us/step
# [Kmeans, DAE] Silhouette: 0.7381
# Evaluation: embeddings 5, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 712us/step
# [Kmeans, DAE] Silhouette: 0.7544
# Evaluation: embeddings 5, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 696us/step
# [Kmeans, DAE] Silhouette: 0.7529
# Evaluation: embeddings 5, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step
# [Kmeans, DAE] Silhouette: 0.7444
# Evaluation: embeddings 5, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step
# [Kmeans, DAE] Silhouette: 0.7737
# Evaluation: embeddings 5, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step
# [Kmeans, DAE] Silhouette: 0.7686
# Evaluation: embeddings 5, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 657us/step
# [Kmeans, DAE] Silhouette: 0.8069
# Evaluation: embeddings 5, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 679us/step
# [Kmeans, DAE] Silhouette: 0.7545
# Evaluation: embeddings 5, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 652us/step
# [Kmeans, DAE] Silhouette: 0.7189
# Evaluation: embeddings 5, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 655us/step
# [Kmeans, DAE] Silhouette: 0.7544
# Evaluation: embeddings 5, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 648us/step
# [Kmeans, DAE] Silhouette: 0.7517
# Evaluation: embeddings 5, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 649us/step
# [Kmeans, DAE] Silhouette: 0.7539
# Evaluation: embeddings 5, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 650us/step
# [Kmeans, DAE] Silhouette: 0.7295
# Evaluation: embeddings 6, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step
# [Kmeans, DAE] Silhouette: 0.9058
# Evaluation: embeddings 6, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 655us/step
# [Kmeans, DAE] Silhouette: 0.8527
# Evaluation: embeddings 6, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 723us/step
# [Kmeans, DAE] Silhouette: 0.7956
# Evaluation: embeddings 6, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step
# [Kmeans, DAE] Silhouette: 0.8843
# Evaluation: embeddings 6, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 657us/step
# [Kmeans, DAE] Silhouette: 0.7357
# Evaluation: embeddings 6, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 668us/step
# [Kmeans, DAE] Silhouette: 0.7478
# Evaluation: embeddings 6, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# [Kmeans, DAE] Silhouette: 0.8066
# Evaluation: embeddings 6, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 667us/step
# [Kmeans, DAE] Silhouette: 0.7637
# Evaluation: embeddings 6, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 681us/step
# [Kmeans, DAE] Silhouette: 0.7779
# Evaluation: embeddings 6, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step
# [Kmeans, DAE] Silhouette: 0.8269
# Evaluation: embeddings 6, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 701us/step
# [Kmeans, DAE] Silhouette: 0.7776
# Evaluation: embeddings 6, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step
# [Kmeans, DAE] Silhouette: 0.7755
# Evaluation: embeddings 6, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 659us/step
# [Kmeans, DAE] Silhouette: 0.7532
# Evaluation: embeddings 6, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step
# [Kmeans, DAE] Silhouette: 0.7675
# Evaluation: embeddings 6, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.7688
# Evaluation: embeddings 6, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 683us/step
# [Kmeans, DAE] Silhouette: 0.7956
# Evaluation: embeddings 6, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step
# [Kmeans, DAE] Silhouette: 0.7862
# Evaluation: embeddings 6, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.7674
# Evaluation: embeddings 6, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 656us/step
# [Kmeans, DAE] Silhouette: 0.7744
# Evaluation: embeddings 6, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step
# [Kmeans, DAE] Silhouette: 0.7871
# Evaluation: embeddings 6, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 660us/step
# [Kmeans, DAE] Silhouette: 0.7563
# Evaluation: embeddings 6, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step
# [Kmeans, DAE] Silhouette: 0.7671
# Evaluation: embeddings 6, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 669us/step
# [Kmeans, DAE] Silhouette: 0.7513
# Evaluation: embeddings 6, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.7639
# Evaluation: embeddings 6, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 663us/step
# [Kmeans, DAE] Silhouette: 0.7511
# Evaluation: embeddings 6, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 664us/step
# [Kmeans, DAE] Silhouette: 0.7724
# Evaluation: embeddings 6, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step
# [Kmeans, DAE] Silhouette: 0.7478
# Evaluation: embeddings 6, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 663us/step
# [Kmeans, DAE] Silhouette: 0.7439
# Evaluation: embeddings 6, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 680us/step
# [Kmeans, DAE] Silhouette: 0.7590
# Evaluation: embeddings 6, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# [Kmeans, DAE] Silhouette: 0.7507
# Evaluation: embeddings 6, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step
# [Kmeans, DAE] Silhouette: 0.8003
# Evaluation: embeddings 6, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 679us/step
# [Kmeans, DAE] Silhouette: 0.7457
# Evaluation: embeddings 6, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 673us/step
# [Kmeans, DAE] Silhouette: 0.7405
# Evaluation: embeddings 6, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 679us/step
# [Kmeans, DAE] Silhouette: 0.7420
# Evaluation: embeddings 6, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7743
# Evaluation: embeddings 7, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 612us/step
# [Kmeans, DAE] Silhouette: 0.9524
# Evaluation: embeddings 7, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 690us/step
# [Kmeans, DAE] Silhouette: 0.7729
# Evaluation: embeddings 7, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 656us/step
# [Kmeans, DAE] Silhouette: 0.8620
# Evaluation: embeddings 7, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step
# [Kmeans, DAE] Silhouette: 0.7986
# Evaluation: embeddings 7, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 692us/step
# [Kmeans, DAE] Silhouette: 0.8540
# Evaluation: embeddings 7, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step
# [Kmeans, DAE] Silhouette: 0.8068
# Evaluation: embeddings 7, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
# [Kmeans, DAE] Silhouette: 0.7948
# Evaluation: embeddings 7, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 630us/step
# [Kmeans, DAE] Silhouette: 0.8224
# Evaluation: embeddings 7, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step
# [Kmeans, DAE] Silhouette: 0.7800
# Evaluation: embeddings 7, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 621us/step
# [Kmeans, DAE] Silhouette: 0.8672
# Evaluation: embeddings 7, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 634us/step
# [Kmeans, DAE] Silhouette: 0.7525
# Evaluation: embeddings 7, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 635us/step
# [Kmeans, DAE] Silhouette: 0.7668
# Evaluation: embeddings 7, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 665us/step
# [Kmeans, DAE] Silhouette: 0.7637
# Evaluation: embeddings 7, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 675us/step
# [Kmeans, DAE] Silhouette: 0.7670
# Evaluation: embeddings 7, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 690us/step
# [Kmeans, DAE] Silhouette: 0.7625
# Evaluation: embeddings 7, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# [Kmeans, DAE] Silhouette: 0.7481
# Evaluation: embeddings 7, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 619us/step
# [Kmeans, DAE] Silhouette: 0.7682
# Evaluation: embeddings 7, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 577us/step
# [Kmeans, DAE] Silhouette: 0.7535
# Evaluation: embeddings 7, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 599us/step
# [Kmeans, DAE] Silhouette: 0.7621
# Evaluation: embeddings 7, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 589us/step
# [Kmeans, DAE] Silhouette: 0.7829
# Evaluation: embeddings 7, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 608us/step
# [Kmeans, DAE] Silhouette: 0.7687
# Evaluation: embeddings 7, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 630us/step
# [Kmeans, DAE] Silhouette: 0.7446
# Evaluation: embeddings 7, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step
# [Kmeans, DAE] Silhouette: 0.7587
# Evaluation: embeddings 7, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 673us/step
# [Kmeans, DAE] Silhouette: 0.7428
# Evaluation: embeddings 7, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 620us/step
# [Kmeans, DAE] Silhouette: 0.7736
# Evaluation: embeddings 7, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 603us/step
# [Kmeans, DAE] Silhouette: 0.7563
# Evaluation: embeddings 7, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 591us/step
# [Kmeans, DAE] Silhouette: 0.7277
# Evaluation: embeddings 7, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 683us/step
# [Kmeans, DAE] Silhouette: 0.7502
# Evaluation: embeddings 7, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 637us/step
# [Kmeans, DAE] Silhouette: 0.7488
# Evaluation: embeddings 7, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 649us/step
# [Kmeans, DAE] Silhouette: 0.7421
# Evaluation: embeddings 7, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 685us/step
# [Kmeans, DAE] Silhouette: 0.7433
# Evaluation: embeddings 7, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 718us/step
# [Kmeans, DAE] Silhouette: 0.7620
# Evaluation: embeddings 7, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 3s 812us/step
# [Kmeans, DAE] Silhouette: 0.7709
# Evaluation: embeddings 7, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step
# [Kmeans, DAE] Silhouette: 0.7342
# Evaluation: embeddings 7, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 690us/step
# [Kmeans, DAE] Silhouette: 0.7288
# Evaluation: embeddings 8, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 697us/step
# [Kmeans, DAE] Silhouette: 0.8049
# Evaluation: embeddings 8, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# [Kmeans, DAE] Silhouette: 0.8122
# Evaluation: embeddings 8, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 665us/step
# [Kmeans, DAE] Silhouette: 0.8588
# Evaluation: embeddings 8, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 671us/step
# [Kmeans, DAE] Silhouette: 0.8401
# Evaluation: embeddings 8, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step
# [Kmeans, DAE] Silhouette: 0.9571
# Evaluation: embeddings 8, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step
# [Kmeans, DAE] Silhouette: 0.7774
# Evaluation: embeddings 8, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 705us/step
# [Kmeans, DAE] Silhouette: 0.7476
# Evaluation: embeddings 8, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 715us/step
# [Kmeans, DAE] Silhouette: 0.7562
# Evaluation: embeddings 8, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 701us/step
# [Kmeans, DAE] Silhouette: 0.7639
# Evaluation: embeddings 8, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step
# [Kmeans, DAE] Silhouette: 0.9435
# Evaluation: embeddings 8, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step
# [Kmeans, DAE] Silhouette: 0.7712
# Evaluation: embeddings 8, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 635us/step
# [Kmeans, DAE] Silhouette: 0.7713
# Evaluation: embeddings 8, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 652us/step
# [Kmeans, DAE] Silhouette: 0.7398
# Evaluation: embeddings 8, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 644us/step
# [Kmeans, DAE] Silhouette: 0.7499
# Evaluation: embeddings 8, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 668us/step
# [Kmeans, DAE] Silhouette: 0.7566
# Evaluation: embeddings 8, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 654us/step
# [Kmeans, DAE] Silhouette: 0.7678
# Evaluation: embeddings 8, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step
# [Kmeans, DAE] Silhouette: 0.7366
# Evaluation: embeddings 8, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 711us/step
# [Kmeans, DAE] Silhouette: 0.7776
# Evaluation: embeddings 8, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 713us/step
# [Kmeans, DAE] Silhouette: 0.7391
# Evaluation: embeddings 8, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 691us/step
# [Kmeans, DAE] Silhouette: 0.7450
# Evaluation: embeddings 8, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 602us/step
# [Kmeans, DAE] Silhouette: 0.7505
# Evaluation: embeddings 8, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 659us/step
# [Kmeans, DAE] Silhouette: 0.7397
# Evaluation: embeddings 8, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 652us/step
# [Kmeans, DAE] Silhouette: 0.7601
# Evaluation: embeddings 8, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 651us/step
# [Kmeans, DAE] Silhouette: 0.7507
# Evaluation: embeddings 8, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# [Kmeans, DAE] Silhouette: 0.7380
# Evaluation: embeddings 8, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 645us/step
# [Kmeans, DAE] Silhouette: 0.7538
# Evaluation: embeddings 8, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 606us/step
# [Kmeans, DAE] Silhouette: 0.7497
# Evaluation: embeddings 8, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 672us/step
# [Kmeans, DAE] Silhouette: 0.7382
# Evaluation: embeddings 8, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 674us/step
# [Kmeans, DAE] Silhouette: 0.7551
# Evaluation: embeddings 8, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7547
# Evaluation: embeddings 8, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 695us/step
# [Kmeans, DAE] Silhouette: 0.7451
# Evaluation: embeddings 8, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 706us/step
# [Kmeans, DAE] Silhouette: 0.7538
# Evaluation: embeddings 8, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 733us/step
# [Kmeans, DAE] Silhouette: 0.7553
# Evaluation: embeddings 8, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 735us/step
# [Kmeans, DAE] Silhouette: 0.7487
# Evaluation: embeddings 8, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 775us/step
# [Kmeans, DAE] Silhouette: 0.7386
# Evaluation: embeddings 9, epoch 2, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step
# [Kmeans, DAE] Silhouette: 0.7859
# Evaluation: embeddings 9, epoch 2, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 662us/step
# [Kmeans, DAE] Silhouette: 0.8213
# Evaluation: embeddings 9, epoch 2, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 661us/step
# [Kmeans, DAE] Silhouette: 0.8906
# Evaluation: embeddings 9, epoch 2, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step
# [Kmeans, DAE] Silhouette: 0.8546
# Evaluation: embeddings 9, epoch 2, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 702us/step
# [Kmeans, DAE] Silhouette: 0.8050
# Evaluation: embeddings 9, epoch 3, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 718us/step
# [Kmeans, DAE] Silhouette: 0.7341
# Evaluation: embeddings 9, epoch 3, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 726us/step
# [Kmeans, DAE] Silhouette: 0.7582
# Evaluation: embeddings 9, epoch 3, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 746us/step
# [Kmeans, DAE] Silhouette: 0.8262
# Evaluation: embeddings 9, epoch 3, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step
# [Kmeans, DAE] Silhouette: 0.7821
# Evaluation: embeddings 9, epoch 3, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 679us/step
# [Kmeans, DAE] Silhouette: 0.7839
# Evaluation: embeddings 9, epoch 4, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 704us/step
# [Kmeans, DAE] Silhouette: 0.7635
# Evaluation: embeddings 9, epoch 4, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 690us/step
# [Kmeans, DAE] Silhouette: 0.8091
# Evaluation: embeddings 9, epoch 4, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 615us/step
# [Kmeans, DAE] Silhouette: 0.8109
# Evaluation: embeddings 9, epoch 4, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step
# [Kmeans, DAE] Silhouette: 0.7649
# Evaluation: embeddings 9, epoch 4, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 622us/step
# [Kmeans, DAE] Silhouette: 0.8260
# Evaluation: embeddings 9, epoch 5, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 694us/step
# [Kmeans, DAE] Silhouette: 0.7678
# Evaluation: embeddings 9, epoch 5, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 710us/step
# [Kmeans, DAE] Silhouette: 0.7509
# Evaluation: embeddings 9, epoch 5, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step
# [Kmeans, DAE] Silhouette: 0.7495
# Evaluation: embeddings 9, epoch 5, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 689us/step
# [Kmeans, DAE] Silhouette: 0.7719
# Evaluation: embeddings 9, epoch 5, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 705us/step
# [Kmeans, DAE] Silhouette: 0.7447
# Evaluation: embeddings 9, epoch 6, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 700us/step
# [Kmeans, DAE] Silhouette: 0.7595
# Evaluation: embeddings 9, epoch 6, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 693us/step
# [Kmeans, DAE] Silhouette: 0.7598
# Evaluation: embeddings 9, epoch 6, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 703us/step
# [Kmeans, DAE] Silhouette: 0.7322
# Evaluation: embeddings 9, epoch 6, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 717us/step
# [Kmeans, DAE] Silhouette: 0.7464
# Evaluation: embeddings 9, epoch 6, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 698us/step
# [Kmeans, DAE] Silhouette: 0.7515
# Evaluation: embeddings 9, epoch 7, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 716us/step
# [Kmeans, DAE] Silhouette: 0.7612
# Evaluation: embeddings 9, epoch 7, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 699us/step
# [Kmeans, DAE] Silhouette: 0.8004
# Evaluation: embeddings 9, epoch 7, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 719us/step
# [Kmeans, DAE] Silhouette: 0.7515
# Evaluation: embeddings 9, epoch 7, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 678us/step
# [Kmeans, DAE] Silhouette: 0.7258
# Evaluation: embeddings 9, epoch 7, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step
# [Kmeans, DAE] Silhouette: 0.7424
# Evaluation: embeddings 9, epoch 8, eval # 1:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 683us/step
# [Kmeans, DAE] Silhouette: 0.7718
# Evaluation: embeddings 9, epoch 8, eval # 2:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 685us/step
# [Kmeans, DAE] Silhouette: 0.7379
# Evaluation: embeddings 9, epoch 8, eval # 3:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 635us/step
# [Kmeans, DAE] Silhouette: 0.7466
# Evaluation: embeddings 9, epoch 8, eval # 4:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 688us/step
# [Kmeans, DAE] Silhouette: 0.8225
# Evaluation: embeddings 9, epoch 8, eval # 5:
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 2s 687us/step
# [Kmeans, DAE] Silhouette: 0.7470
# Silhouette: 0.9631
# Best parameters: 3_5_2048_linear

# %%
dae_embeds, dae_model = DAE_reduction(bank_reserves, 5, 2, 2048)
dae_kmeans_labels = KMeans(n_clusters=3, random_state=42, n_init=10).fit(dae_embeds).labels_
score = sil_score(dae_embeds, dae_kmeans_labels, sil_sample)
