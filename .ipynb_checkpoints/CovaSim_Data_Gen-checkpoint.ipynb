# %%
import covasim as cv
import numpy as np
# Out:
# Covasim 3.1.6 (2024-01-28) — © 2020-2024 by IDM
# Initializing sim with 20000 people for 60 days
#   Running 2020-03-01 ( 0/60) (0.78 s)  ———————————————————— 2%
#   Running 2020-03-11 (10/60) (0.93 s)  •••————————————————— 18%
#   Running 2020-03-21 (20/60) (1.16 s)  ••••••—————————————— 34%
#   Running 2020-03-31 (30/60) (1.27 s)  ••••••••••—————————— 51%
#   Running 2020-04-10 (40/60) (1.60 s)  •••••••••••••——————— 67%
#   Running 2020-04-20 (50/60) (1.75 s)  ••••••••••••••••———— 84%
#   Running 2020-04-30 (60/60) (2.19 s)  •••••••••••••••••••• 100%
#
# Simulation summary:
#        12,730 cumulative infections
#           596 cumulative reinfections
#        10,182 cumulative infectious
#         6,395 cumulative symptomatic cases
#           386 cumulative severe cases
#           114 cumulative critical cases
#         5,159 cumulative recoveries
#            14 cumulative deaths
#             0 cumulative tests
#             0 cumulative diagnoses
# ...

# %%
with open('covasim_inputs.csv', 'w', newline='') as covasim_inputs, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_, \
    open('covasim_outputs_.csv', 'w', newline='') as covasim_outputs_:
    for i in np.arange(10):
        beta = np.random.uniform(0.01, 0.025)
        rel_symp_prob = np.random.uniform(0.5, 1.2)
        rel_severe_prob = np.random.uniform(0.3, 3)
        rel_crit_prob = np.random.uniform(0.7, 5)
        rel_death_prob = np.random.uniform(0.5, 2)
        pars = dict(
            pop_size = 50e3,
            pop_infected = 100,
            n_days = 200,
            beta = beta,
            rel_symp_prob = rel_symp_prob,
            rel_severe_prob = rel_severe_prob,
            rel_crit_prob = rel_crit_prob,
            rel_death_prob = rel_death_prob
        )
        sim = cv.Sim(pars)
        sim.run()
        print([beta, rel_symp_prob, rel_severe_prob, rel_crit_prob, rel_death_prob], file=covasim_inputs)
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
        print(, file=covasim_outputs_, sep=",")
covasim_inputs.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()
covasim_outputs_.close()

# %%
sim.results['cum_infections'].values
# Out:
# array([   20.,    21.,    21.,    23.,    28.,    37.,    40.,    45.,
#           50.,    59.,    67.,    76.,    83.,    93.,   106.,   131.,
#          145.,   161.,   179.,   209.,   258.,   292.,   333.,   369.,
#          423.,   480.,   534.,   625.,   685.,   772.,   874.,   998.,
#         1127.,  1290.,  1458.,  1622.,  1819.,  2033.,  2270.,  2504.,
#         2759.,  3072.,  3390.,  3774.,  4170.,  4563.,  4997.,  5471.,
#         5960.,  6428.,  6992.,  7570.,  8098.,  8639.,  9246.,  9859.,
#        10482., 11080., 11670., 12188., 12730.])

# %%
sim.results['cum_infectious'].values
# Out:
# array([0.0000e+00, 1.0000e+00, 1.0000e+00, 8.0000e+00, 1.6000e+01,
#        2.0000e+01, 2.0000e+01, 2.2000e+01, 2.9000e+01, 3.3000e+01,
#        3.7000e+01, 4.2000e+01, 4.6000e+01, 5.5000e+01, 6.1000e+01,
#        6.8000e+01, 8.1000e+01, 9.0000e+01, 1.0400e+02, 1.2200e+02,
#        1.4100e+02, 1.5500e+02, 1.7300e+02, 1.9900e+02, 2.3600e+02,
#        2.6800e+02, 3.0500e+02, 3.5400e+02, 3.8800e+02, 4.4500e+02,
#        5.1900e+02, 5.8300e+02, 6.6300e+02, 7.4800e+02, 8.4200e+02,
#        9.5300e+02, 1.0850e+03, 1.2180e+03, 1.3750e+03, 1.5360e+03,
#        1.7110e+03, 1.9340e+03, 2.1780e+03, 2.4190e+03, 2.6910e+03,
#        2.9580e+03, 3.2880e+03, 3.6140e+03, 3.9870e+03, 4.3720e+03,
#        4.7870e+03, 5.2600e+03, 5.7150e+03, 6.2170e+03, 6.7480e+03,
#        7.2980e+03, 7.8460e+03, 8.3910e+03, 8.9810e+03, 9.5600e+03,
#        1.0182e+04])

# %%
sim.results['cum_symptomatic'].values

# %%
sim.results['cum_severe'].values

# %%
sim.results['cum_critical'].values

# %%
sim.results['cum_deaths'].values

# %%
sim.results['incidence'].values

# %%
sim.results['prevalence'].values

# %%
sim.results['r_eff'].values
